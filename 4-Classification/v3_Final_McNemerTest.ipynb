# %% [markdown]
# #### Main Objective: To perform McNemer's test on the results of all the (a) binary classifiers (b) multi-class classifiers
# 1. Binary Classifiers:
#     a. Decision Tree
#     b. Random Forest
#     c. XGBoost
#     d. Logistic Regression
#     e. Gradient Boosting Classifier
#     f. Decision Tree
#     g. MLPClassifier
#
# 2. Multi-Class Classifiers:
#     a. Decision Tree
#     b. Random Forest
#     c. XGBoost
#     d. Logistic Regression
#     e. Gradient Boosting Classifier
#     f. Decision Tree
#     g. MLPClassifier

# %% [markdown]
# ##### 1. Binary Classifiers:

# %%
import numpy as np
from mlxtend.evaluate import mcnemar


# Confusion matrices for each NaN classifier
nan_tb_rf = np.array([[3808, 33], [672, 23]])

nan_tb_dt = np.array([[3281, 560], [543, 152]])

nan_tb_gb = np.array([[3837, 4], [689, 6]])

# tb_mlp = np.array([[1735, 2102],
#                  [286, 367]])

nan_tb_xgb = np.array([[3792, 49], [663, 32]])

nan_tb_lr = np.array([[3821, 20], [687, 8]])

nan_tb_mlp = np.array([[3613, 228], [601, 94]])

# Confusion matrices for each custom weight technique classifier
custom_tb_rf = np.array([[701, 3140], [59, 636]])

custom_tb_dt = np.array([[3273, 568], [526, 169]])

custom_tb_gb = np.array([[3839, 2], [692, 3]])

custom_tb_xgb = np.array([[3814, 27], [664, 31]])

custom_tb_lr = np.array([[3834, 7], [692, 3]])

# Confusion matrices for each balanced classifier
balanced_tb_rf = np.array([[3797, 44], [674, 21]])

balanced_tb_dt = np.array([[3319, 522], [524, 171]])

balanced_tb_gb = np.array([[2348, 1493], [207, 488]])

balanced_tb_xgb = np.array([[2796, 1045], [325, 370]])

balanced_tb_lr = np.array([[2312, 1529], [232, 463]])


# Confusion matrices for each oversample classifier

oversampling_tb_rf = np.array([[3704, 137], [625, 70]])

oversampling_tb_dt = np.array([[3242, 599], [506, 189]])

oversampling_tb_gb = np.array([[1872, 1969], [149, 546]])

oversampling_tb_xgb = np.array([[1750, 2091], [245, 450]])

oversampling_tb_lr = np.array([[2040, 1801], [187, 508]])

oversampling_tb_mlp = np.array([[2267, 1574], [326, 369]])

# List of confusion matrices
conf_matrices = {
    # for each NaN classifier
    "NaN_RF": nan_tb_rf,
    "NaN_DT": nan_tb_dt,
    "NaN_GB": nan_tb_gb,
    "NaN_XGB": nan_tb_xgb,
    "NaN_LR": nan_tb_lr,
    "NaN_MLP": nan_tb_mlp,
    # for each balanced class weight technique classifier
    "custom_RF": custom_tb_rf,
    "custom_DT": custom_tb_dt,
    "custom_GB": custom_tb_gb,
    "custom_XGB": custom_tb_xgb,
    "custom_LR": custom_tb_lr,
    # for each balanced class weight technique classifier
    "balanced_DT": balanced_tb_dt,
    "balanced_GB": balanced_tb_gb,
    "balanced_LR": balanced_tb_lr,
    "balanced_RF": balanced_tb_rf,
    "balanced_XGB": balanced_tb_xgb,
    # for each oversample classifier
    "oversampling_DT": oversampling_tb_dt,
    "oversampling_GB": oversampling_tb_gb,
    "oversampling_LR": oversampling_tb_lr,
    "oversampling_RF": oversampling_tb_rf,
    "oversampling_XGB": oversampling_tb_xgb,
    "oversampling_MLP": oversampling_tb_mlp,
}


# Function to perform McNemar test and print results
def perform_mcnemar_test(matrix1, matrix2, name1, name2):
    b = matrix1[0, 1] + matrix1[1, 0]
    c = matrix2[0, 1] + matrix2[1, 0]
    contingency_table = np.array(
        [[matrix1[0, 0] + matrix2[0, 0], b], [c, matrix1[1, 1] + matrix2[1, 1]]]
    )
    chi2, p = mcnemar(ary=contingency_table, corrected=True)
    print(f"McNemar Test between {name1} and {name2}")
    print("Chi-squared:", chi2)
    print("p-value:", p)
    print("-" * 30)


# Compare all pairs of classifiers
for name1, matrix1 in conf_matrices.items():
    for name2, matrix2 in conf_matrices.items():
        if name1 != name2:
            perform_mcnemar_test(matrix1, matrix2, name1, name2)

## Conclusion

# '''XGBoost (XGB) and Decision Tree (DT): There is no statistically significant difference between these two classifiers.
# All other pairs: Show statistically significant differences in their performance.
# The XGBoost classifier's performance is similar to the Decision Tree classifier, as indicated by the non-significant p-value.
# All other comparisons between classifiers indicate statistically significant differences, suggesting that these classifiers perform differently from each other on the given dataset.
# ''''''
# Out:
# McNemar Test between NaN_RF and NaN_DT
# Chi-squared: 87.17311946902655
# p-value: 9.942596260370355e-21
# ------------------------------
# McNemar Test between NaN_RF and NaN_GB
# Chi-squared: 0.08655221745350501
# p-value: 0.7686069279587817
# ------------------------------
# McNemar Test between NaN_RF and NaN_XGB
# Chi-squared: 0.025405786873676783
# p-value: 0.8733600977337836
# ------------------------------
# McNemar Test between NaN_RF and NaN_LR
# Chi-squared: 0.000708215297450425
# p-value: 0.97876895097249
# ------------------------------
# McNemar Test between NaN_RF and NaN_MLP
# Chi-squared: 9.86245110821382
# p-value: 0.0016868621629592758
# ------------------------------
# McNemar Test between NaN_RF and custom_RF
# Chi-squared: 1591.969518442623
# p-value: 0.0
# ------------------------------
# McNemar Test between NaN_RF and custom_DT
# Chi-squared: 83.68204558087827
# p-value: 5.811060490224053e-20
# ------------------------------
# McNemar Test between NaN_RF and custom_GB
# Chi-squared: 0.07147962830593281
# p-value: 0.7891945011930637
# ------------------------------
# McNemar Test between NaN_RF and custom_XGB
# Chi-squared: 0.12106017191977077
# p-value: 0.7278874800949906
# ------------------------------
# McNemar Test between NaN_RF and custom_LR
# Chi-squared: 0.017806267806267807
# p-value: 0.8938453114675831
# ------------------------------
# McNemar Test between NaN_RF and balanced_DT
# Chi-squared: 66.01941747572816
# p-value: 4.465024479510059e-16
# ------------------------------
# McNemar Test between NaN_RF and balanced_GB
# Chi-squared: 410.8257796257796
# p-value: 2.4231254065792547e-91
# ------------------------------
# McNemar Test between NaN_RF and balanced_LR
# Chi-squared: 451.3483373884834
# p-value: 3.6701264069664985e-100
# ------------------------------
# McNemar Test between NaN_RF and balanced_RF
# Chi-squared: 0.10119465917076599
# p-value: 0.7504006792929829
# ------------------------------
# McNemar Test between NaN_RF and balanced_XGB
# Chi-squared: 212.48
# p-value: 3.9519810396450174e-48
# ------------------------------
# McNemar Test between NaN_RF and oversampling_DT
# Chi-squared: 87.95635359116022
# p-value: 6.69148309130248e-21
# ------------------------------
# McNemar Test between NaN_RF and oversampling_GB
# Chi-squared: 706.2500885582714
# p-value: 1.3079462080179961e-155
# ------------------------------
# McNemar Test between NaN_RF and oversampling_LR
# Chi-squared: 610.2948384701077
# p-value: 9.65208526499904e-135
# ------------------------------
# McNemar Test between NaN_RF and oversampling_RF
# Chi-squared: 2.137695978186776
# p-value: 0.14371759718504554
# ------------------------------
# McNemar Test between NaN_RF and oversampling_XGB
# Chi-squared: 873.6928641894114
# p-value: 5.137716126256608e-192
# ------------------------------
# McNemar Test between NaN_RF and oversampling_MLP
# Chi-squared: 547.2690978886757
# p-value: 4.943960134272382e-121
# ------------------------------
# McNemar Test between NaN_DT and NaN_RF
# Chi-squared: 87.17311946902655
# p-value: 9.942596260370355e-21
# ------------------------------
# McNemar Test between NaN_DT and NaN_GB
# Chi-squared: 93.14086859688196
# p-value: 4.870163062345951e-22
# ------------------------------
# McNemar Test between NaN_DT and NaN_XGB
# Chi-squared: 83.80165289256199
# p-value: 5.469905838446654e-20
# ------------------------------
# McNemar Test between NaN_DT and NaN_LR
# Chi-squared: 86.20165745856353
# p-value: 1.6249141811379697e-20
# ------------------------------
# McNemar Test between NaN_DT and NaN_MLP
# Chi-squared: 38.57608695652174
# p-value: 5.266018335207004e-10
# ------------------------------
# McNemar Test between NaN_DT and custom_RF
# Chi-squared: 1020.2289632728963
# p-value: 7.198832659893845e-224
# ------------------------------
# McNemar Test between NaN_DT and custom_DT
# Chi-squared: 0.02913063268092854
# p-value: 0.8644777617925989
# ------------------------------
# McNemar Test between NaN_DT and custom_GB
# Chi-squared: 92.63439065108514
# p-value: 6.290477128073146e-22
# ------------------------------
# McNemar Test between NaN_DT and custom_XGB
# Chi-squared: 94.15886287625418
# p-value: 2.91189899040355e-22
# ------------------------------
# McNemar Test between NaN_DT and custom_LR
# Chi-squared: 90.12708102108768
# p-value: 2.2334365283165254e-21
# ------------------------------
# McNemar Test between NaN_DT and balanced_DT
# Chi-squared: 1.4592833876221498
# p-value: 0.22704417568560456
# ------------------------------
# McNemar Test between NaN_DT and balanced_GB
# Chi-squared: 126.72707813057438
# p-value: 2.131611660860777e-29
# ------------------------------
# McNemar Test between NaN_DT and balanced_LR
# Chi-squared: 150.71543296089385
# p-value: 1.2094433000765364e-34
# ------------------------------
# McNemar Test between NaN_DT and balanced_RF
# Chi-squared: 80.97528830313014
# p-value: 2.2855797066406433e-19
# ------------------------------
# McNemar Test between NaN_DT and balanced_XGB
# Chi-squared: 28.61140315406389
# p-value: 8.845971476645048e-08
# ------------------------------
# McNemar Test between NaN_DT and oversampling_DT
# Chi-squared: 0.0004528985507246377
# p-value: 0.9830211705448397
# ------------------------------
# McNemar Test between NaN_DT and oversampling_GB
# Chi-squared: 319.2163924247128
# p-value: 2.1457967316027103e-71
# ------------------------------
# McNemar Test between NaN_DT and oversampling_LR
# Chi-squared: 252.81656421869945
# p-value: 6.315631061486563e-57
# ------------------------------
# McNemar Test between NaN_DT and oversampling_RF
# Chi-squared: 61.983914209115284
# p-value: 3.4627442169383385e-15
# ------------------------------
# McNemar Test between NaN_DT and oversampling_XGB
# Chi-squared: 441.3562082000582
# p-value: 5.48635703264321e-98
# ------------------------------
# McNemar Test between NaN_DT and oversampling_MLP
# Chi-squared: 210.994338994339
# p-value: 8.335499015950147e-48
# ------------------------------
# McNemar Test between NaN_GB and NaN_RF
# Chi-squared: 0.08655221745350501
# p-value: 0.7686069279587817
# ------------------------------
# McNemar Test between NaN_GB and NaN_DT
# Chi-squared: 93.14086859688196
# p-value: 4.870163062345951e-22
# ------------------------------
# McNemar Test between NaN_GB and NaN_XGB
# Chi-squared: 0.23060498220640568
# p-value: 0.631075605727375
# ------------------------------
# McNemar Test between NaN_GB and NaN_LR
# Chi-squared: 0.12071428571428572
# p-value: 0.7282610766726116
# ------------------------------
# McNemar Test between NaN_GB and NaN_MLP
# Chi-squared: 11.97437582128778
# p-value: 0.0005393713083221278
# ------------------------------
# McNemar Test between NaN_GB and custom_RF
# Chi-squared: 1612.28802672148
# p-value: 0.0
# ------------------------------
# McNemar Test between NaN_GB and custom_DT
# Chi-squared: 89.53553441522104
# p-value: 3.0117995873700273e-21
# ------------------------------
# McNemar Test between NaN_GB and custom_GB
# Chi-squared: 0.0
# p-value: 1.0
# ------------------------------
# McNemar Test between NaN_GB and custom_XGB
# Chi-squared: 0.000722543352601156
# p-value: 0.9785553126188935
# ------------------------------
# McNemar Test between NaN_GB and custom_LR
# Chi-squared: 0.017959770114942528
# p-value: 0.8933914510349967
# ------------------------------
# McNemar Test between NaN_GB and balanced_DT
# Chi-squared: 71.25014376078205
# p-value: 3.146879317816088e-17
# ------------------------------
# McNemar Test between NaN_GB and balanced_GB
# Chi-squared: 422.91516924362725
# p-value: 5.661485067195038e-94
# ------------------------------
# McNemar Test between NaN_GB and balanced_LR
# Chi-squared: 463.9319478402608
# p-value: 6.702538746938167e-103
# ------------------------------
# McNemar Test between NaN_GB and balanced_RF
# Chi-squared: 0.40822111977321046
# p-value: 0.5228737783066646
# ------------------------------
# McNemar Test between NaN_GB and balanced_XGB
# Chi-squared: 221.51042171594764
# p-value: 4.2357186664753737e-50
# ------------------------------
# McNemar Test between NaN_GB and oversampling_DT
# Chi-squared: 93.94938820912125
# p-value: 3.236957518697418e-22
# ------------------------------
# McNemar Test between NaN_GB and oversampling_GB
# Chi-squared: 721.3717538242619
# p-value: 6.735572019622952e-159
# ------------------------------
# McNemar Test between NaN_GB and oversampling_LR
# Chi-squared: 624.5565087653861
# p-value: 7.63376686478644e-138
# ------------------------------
# McNemar Test between NaN_GB and oversampling_RF
# Chi-squared: 3.1780068728522335
# p-value: 0.07463571858375133
# ------------------------------
# McNemar Test between NaN_GB and oversampling_XGB
# Chi-squared: 890.1168702542093
# p-value: 1.3813619870575665e-195
# ------------------------------
# McNemar Test between NaN_GB and oversampling_MLP
# Chi-squared: 560.9086000771307
# p-value: 5.332958826090104e-124
# ------------------------------
# McNemar Test between NaN_XGB and NaN_RF
# Chi-squared: 0.025405786873676783
# p-value: 0.8733600977337836
# ------------------------------
# McNemar Test between NaN_XGB and NaN_DT
# Chi-squared: 83.80165289256199
# p-value: 5.469905838446654e-20
# ------------------------------
# McNemar Test between NaN_XGB and NaN_GB
# Chi-squared: 0.23060498220640568
# p-value: 0.631075605727375
# ------------------------------
# McNemar Test between NaN_XGB and NaN_LR
# Chi-squared: 0.01127554615926709
# p-value: 0.9154344812855018
# ------------------------------
# McNemar Test between NaN_XGB and NaN_MLP
# Chi-squared: 8.7319922128488
# p-value: 0.003126746733734016
# ------------------------------
# McNemar Test between NaN_XGB and custom_RF
# Chi-squared: 1580.2086422909742
# p-value: 0.0
# ------------------------------
# McNemar Test between NaN_XGB and custom_DT
# Chi-squared: 80.37707641196013
# p-value: 3.0936340249828786e-19
# ------------------------------
# McNemar Test between NaN_XGB and custom_GB
# Chi-squared: 0.20554765291607396
# p-value: 0.6502797179783568
# ------------------------------
# McNemar Test between NaN_XGB and custom_XGB
# Chi-squared: 0.2851033499643621
# p-value: 0.5933756433372119
# ------------------------------
# McNemar Test between NaN_XGB and custom_LR
# Chi-squared: 0.10205527994330262
# p-value: 0.7493770206992298
# ------------------------------
# McNemar Test between NaN_XGB and balanced_DT
# Chi-squared: 63.07679180887372
# p-value: 1.9880277737575043e-15
# ------------------------------
# McNemar Test between NaN_XGB and balanced_GB
# Chi-squared: 403.88432835820896
# p-value: 7.8591445348783e-90
# ------------------------------
# McNemar Test between NaN_XGB and balanced_LR
# Chi-squared: 444.11807521229275
# p-value: 1.3746866391324976e-98
# ------------------------------
# McNemar Test between NaN_XGB and balanced_RF
# Chi-squared: 0.017482517482517484
# p-value: 0.8948091185487497
# ------------------------------
# McNemar Test between NaN_XGB and balanced_XGB
# Chi-squared: 207.32420749279538
# p-value: 5.268237351509359e-47
# ------------------------------
# McNemar Test between NaN_XGB and oversampling_DT
# Chi-squared: 84.57017061089708
# p-value: 3.7081778514413563e-20
# ------------------------------
# McNemar Test between NaN_XGB and oversampling_GB
# Chi-squared: 697.535335689046
# p-value: 1.0272187707905863e-153
# ------------------------------
# McNemar Test between NaN_XGB and oversampling_LR
# Chi-squared: 602.0833333333334
# p-value: 5.897375127475112e-133
# ------------------------------
# McNemar Test between NaN_XGB and oversampling_RF
# Chi-squared: 1.6289009497964722
# p-value: 0.20185513004190622
# ------------------------------
# McNemar Test between NaN_XGB and oversampling_XGB
# Chi-squared: 864.2155511811023
# p-value: 5.90344350864916e-190
# ------------------------------
# McNemar Test between NaN_XGB and oversampling_MLP
# Chi-squared: 539.4215160796325
# p-value: 2.5193040704082326e-119
# ------------------------------
# McNemar Test between NaN_LR and NaN_RF
# Chi-squared: 0.000708215297450425
# p-value: 0.97876895097249
# ------------------------------
# McNemar Test between NaN_LR and NaN_DT
# Chi-squared: 86.20165745856353
# p-value: 1.6249141811379697e-20
# ------------------------------
# McNemar Test between NaN_LR and NaN_GB
# Chi-squared: 0.12071428571428572
# p-value: 0.7282610766726116
# ------------------------------
# McNemar Test between NaN_LR and NaN_XGB
# Chi-squared: 0.01127554615926709
# p-value: 0.9154344812855018
# ------------------------------
# McNemar Test between NaN_LR and NaN_MLP
# Chi-squared: 9.531901041666666
# p-value: 0.0020193084674220703
# ------------------------------
# McNemar Test between NaN_LR and custom_RF
# Chi-squared: 1588.6024065540194
# p-value: 0.0
# ------------------------------
# McNemar Test between NaN_LR and custom_DT
# Chi-squared: 82.72959466962799
# p-value: 9.408204167591359e-20
# ------------------------------
# McNemar Test between NaN_LR and custom_GB
# Chi-squared: 0.10278372591006424
# p-value: 0.7485142871231578
# ------------------------------
# McNemar Test between NaN_LR and custom_XGB
# Chi-squared: 0.1609442060085837
# p-value: 0.6882886930855607
# ------------------------------
# McNemar Test between NaN_LR and custom_LR
# Chi-squared: 0.03485064011379801
# p-value: 0.8519089807859275
# ------------------------------
# McNemar Test between NaN_LR and balanced_DT
# Chi-squared: 65.17056474614945
# p-value: 6.868789029563106e-16
# ------------------------------
# McNemar Test between NaN_LR and balanced_GB
# Chi-squared: 408.8342334856668
# p-value: 6.574833661438862e-91
# ------------------------------
# McNemar Test between NaN_LR and balanced_LR
# Chi-squared: 449.2743111831442
# p-value: 1.0376379027752485e-99
# ------------------------------
# McNemar Test between NaN_LR and balanced_RF
# Chi-squared: 0.07017543859649122
# p-value: 0.7910815129207817
# ------------------------------
# McNemar Test between NaN_LR and balanced_XGB
# Chi-squared: 210.99855560905152
# p-value: 8.317861390603542e-48
# ------------------------------
# McNemar Test between NaN_LR and oversampling_DT
# Chi-squared: 86.98068432671081
# p-value: 1.0958623602663131e-20
# ------------------------------
# McNemar Test between NaN_LR and oversampling_GB
# Chi-squared: 703.7522123893805
# p-value: 4.568398762128067e-155
# ------------------------------
# McNemar Test between NaN_LR and oversampling_LR
# Chi-squared: 607.9406307977737
# p-value: 3.1381043484618757e-134
# ------------------------------
# McNemar Test between NaN_LR and oversampling_RF
# Chi-squared: 1.9850238257317903
# p-value: 0.1588621561077428
# ------------------------------
# McNemar Test between NaN_LR and oversampling_XGB
# Chi-squared: 870.9773250082155
# p-value: 2.0003978284497796e-191
# ------------------------------
# McNemar Test between NaN_LR and oversampling_MLP
# Chi-squared: 545.0187955504412
# p-value: 1.526206786724482e-120
# ------------------------------
# McNemar Test between NaN_MLP and NaN_RF
# Chi-squared: 9.86245110821382
# p-value: 0.0016868621629592758
# ------------------------------
# McNemar Test between NaN_MLP and NaN_DT
# Chi-squared: 38.57608695652174
# p-value: 5.266018335207004e-10
# ------------------------------
# McNemar Test between NaN_MLP and NaN_GB
# Chi-squared: 11.97437582128778
# p-value: 0.0005393713083221278
# ------------------------------
# McNemar Test between NaN_MLP and NaN_XGB
# Chi-squared: 8.7319922128488
# p-value: 0.003126746733734016
# ------------------------------
# McNemar Test between NaN_MLP and NaN_LR
# Chi-squared: 9.531901041666666
# p-value: 0.0020193084674220703
# ------------------------------
# McNemar Test between NaN_MLP and custom_RF
# Chi-squared: 1393.287239324727
# p-value: 6.041276478614237e-305
# ------------------------------
# McNemar Test between NaN_MLP and custom_DT
# Chi-squared: 36.24336973478939
# p-value: 1.7415148975043095e-09
# ------------------------------
# McNemar Test between NaN_MLP and custom_GB
# Chi-squared: 11.789888378200919
# p-value: 0.0005955330588108187
# ------------------------------
# McNemar Test between NaN_MLP and custom_XGB
# Chi-squared: 12.348026315789474
# p-value: 0.00044145293582150373
# ------------------------------
# McNemar Test between NaN_MLP and custom_LR
# Chi-squared: 10.890706806282722
# p-value: 0.0009664794097113525
# ------------------------------
# McNemar Test between NaN_MLP and balanced_DT
# Chi-squared: 24.8832
# p-value: 6.091093318984882e-07
# ------------------------------
# McNemar Test between NaN_MLP and balanced_GB
# Chi-squared: 299.288256227758
# p-value: 4.7080055866514715e-67
# ------------------------------
# McNemar Test between NaN_MLP and balanced_LR
# Chi-squared: 334.65675675675675
# p-value: 9.301664917166438e-75
# ------------------------------
# McNemar Test between NaN_MLP and balanced_RF
# Chi-squared: 7.821590174531351
# p-value: 0.005162575303065023
# ------------------------------
# McNemar Test between NaN_MLP and balanced_XGB
# Chi-squared: 132.60572987721693
# p-value: 1.1027448085545879e-30
# ------------------------------
# McNemar Test between NaN_MLP and oversampling_DT
# Chi-squared: 39.1028955532575
# p-value: 4.0204727039635224e-10
# ------------------------------
# McNemar Test between NaN_MLP and oversampling_GB
# Chi-squared: 562.9263657957245
# p-value: 1.9410600768126947e-124
# ------------------------------
# McNemar Test between NaN_MLP and oversampling_LR
# Chi-squared: 476.0255591054313
# p-value: 1.5652386075709854e-105
# ------------------------------
# McNemar Test between NaN_MLP and oversampling_RF
# Chi-squared: 2.7379006913890636
# p-value: 0.09799342540934892
# ------------------------------
# McNemar Test between NaN_MLP and oversampling_XGB
# Chi-squared: 716.5990521327014
# p-value: 7.34836902857545e-158
# ------------------------------
# McNemar Test between NaN_MLP and oversampling_MLP
# Chi-squared: 419.53096372297546
# p-value: 3.0870075545316406e-93
# ------------------------------
# McNemar Test between custom_RF and NaN_RF
# Chi-squared: 1591.969518442623
# p-value: 0.0
# ------------------------------
# McNemar Test between custom_RF and NaN_DT
# Chi-squared: 1020.2289632728963
# p-value: 7.198832659893845e-224
# ------------------------------
# McNemar Test between custom_RF and NaN_GB
# Chi-squared: 1612.28802672148
# p-value: 0.0
# ------------------------------
# McNemar Test between custom_RF and NaN_XGB
# Chi-squared: 1580.2086422909742
# p-value: 0.0
# ------------------------------
# McNemar Test between custom_RF and NaN_LR
# Chi-squared: 1588.6024065540194
# p-value: 0.0
# ------------------------------
# McNemar Test between custom_RF and NaN_MLP
# Chi-squared: 1393.287239324727
# p-value: 6.041276478614237e-305
# ------------------------------
# McNemar Test between custom_RF and custom_DT
# Chi-squared: 1031.1707430701142
# p-value: 3.0128174102855683e-226
# ------------------------------
# McNemar Test between custom_RF and custom_GB
# Chi-squared: 1610.5872078088878
# p-value: 0.0
# ------------------------------
# McNemar Test between custom_RF and custom_XGB
# Chi-squared: 1615.6938303341901
# p-value: 0.0
# ------------------------------
# McNemar Test between custom_RF and custom_LR
# Chi-squared: 1602.103899435608
# p-value: 0.0
# ------------------------------
# McNemar Test between custom_RF and balanced_DT
# Chi-squared: 1090.9550058892814
# p-value: 3.0533031951233646e-239
# ------------------------------
# McNemar Test between custom_RF and balanced_GB
# Chi-squared: 458.05348030210246
# p-value: 1.2749392791279642e-101
# ------------------------------
# McNemar Test between custom_RF and balanced_LR
# Chi-squared: 416.32439516129034
# p-value: 1.539903155612523e-92
# ------------------------------
# McNemar Test between custom_RF and balanced_RF
# Chi-squared: 1570.1812611692621
# p-value: 0.0
# ------------------------------
# McNemar Test between custom_RF and balanced_XGB
# Chi-squared: 731.3600350186036
# p-value: 4.533868306505112e-161
# ------------------------------
# McNemar Test between custom_RF and oversampling_DT
# Chi-squared: 1017.808782527881
# p-value: 2.4171987984085717e-223
# ------------------------------
# McNemar Test between custom_RF and oversampling_GB
# Chi-squared: 219.37182621779198
# p-value: 1.239952879818738e-49
# ------------------------------
# McNemar Test between custom_RF and oversampling_LR
# Chi-squared: 282.2633506844033
# p-value: 2.412013715061194e-63
# ------------------------------
# McNemar Test between custom_RF and oversampling_RF
# Chi-squared: 1498.130775056804
# p-value: 0.0
# ------------------------------
# McNemar Test between custom_RF and oversampling_XGB
# Chi-squared: 134.2446251129178
# p-value: 4.830195372502038e-31
# ------------------------------
# McNemar Test between custom_RF and oversampling_MLP
# Chi-squared: 330.4185134340067
# p-value: 7.791745268651168e-74
# ------------------------------
# McNemar Test between custom_DT and NaN_RF
# Chi-squared: 83.68204558087827
# p-value: 5.811060490224053e-20
# ------------------------------
# McNemar Test between custom_DT and NaN_DT
# Chi-squared: 0.02913063268092854
# p-value: 0.8644777617925989
# ------------------------------
# McNemar Test between custom_DT and NaN_GB
# Chi-squared: 89.53553441522104
# p-value: 3.0117995873700273e-21
# ------------------------------
# McNemar Test between custom_DT and NaN_XGB
# Chi-squared: 80.37707641196013
# p-value: 3.0936340249828786e-19
# ------------------------------
# McNemar Test between custom_DT and NaN_LR
# Chi-squared: 82.72959466962799
# p-value: 9.408204167591359e-20
# ------------------------------
# McNemar Test between custom_DT and NaN_MLP
# Chi-squared: 36.24336973478939
# p-value: 1.7415148975043095e-09
# ------------------------------
# McNemar Test between custom_DT and custom_RF
# Chi-squared: 1031.1707430701142
# p-value: 3.0128174102855683e-226
# ------------------------------
# McNemar Test between custom_DT and custom_GB
# Chi-squared: 89.03859060402685
# p-value: 3.871853834709337e-21
# ------------------------------
# McNemar Test between custom_DT and custom_XGB
# Chi-squared: 90.53445378151261
# p-value: 1.81783736162148e-21
# ------------------------------
# McNemar Test between custom_DT and custom_LR
# Chi-squared: 86.57891801450084
# p-value: 1.3427088519326273e-20
# ------------------------------
# McNemar Test between custom_DT and balanced_DT
# Chi-squared: 1.0322429906542057
# p-value: 0.30963243530804374
# ------------------------------
# McNemar Test between custom_DT and balanced_GB
# Chi-squared: 131.00393700787401
# p-value: 2.4711567272027086e-30
# ------------------------------
# McNemar Test between custom_DT and balanced_LR
# Chi-squared: 155.36112084063046
# p-value: 1.1675577625683338e-35
# ------------------------------
# McNemar Test between custom_DT and balanced_RF
# Chi-squared: 77.60761589403974
# p-value: 1.2568456516799886e-18
# ------------------------------
# McNemar Test between custom_DT and balanced_XGB
# Chi-squared: 30.691964285714285
# p-value: 3.0241486541393214e-08
# ------------------------------
# McNemar Test between custom_DT and oversampling_DT
# Chi-squared: 0.04547521600727603
# p-value: 0.8311326043402728
# ------------------------------
# McNemar Test between custom_DT and oversampling_GB
# Chi-squared: 325.81849315068496
# p-value: 7.826047862292384e-73
# ------------------------------
# McNemar Test between custom_DT and oversampling_LR
# Chi-squared: 258.74399740428294
# p-value: 3.223273929039713e-58
# ------------------------------
# McNemar Test between custom_DT and oversampling_RF
# Chi-squared: 59.030711206896555
# p-value: 1.5523018277069523e-14
# ------------------------------
# McNemar Test between custom_DT and oversampling_XGB
# Chi-squared: 449.00320699708453
# p-value: 1.188627703020457e-99
# ------------------------------
# McNemar Test between custom_DT and oversampling_MLP
# Chi-squared: 216.44121576486305
# p-value: 5.403478010395484e-49
# ------------------------------
# McNemar Test between custom_GB and NaN_RF
# Chi-squared: 0.07147962830593281
# p-value: 0.7891945011930637
# ------------------------------
# McNemar Test between custom_GB and NaN_DT
# Chi-squared: 92.63439065108514
# p-value: 6.290477128073146e-22
# ------------------------------
# McNemar Test between custom_GB and NaN_GB
# Chi-squared: 0.0
# p-value: 1.0
# ------------------------------
# McNemar Test between custom_GB and NaN_XGB
# Chi-squared: 0.20554765291607396
# p-value: 0.6502797179783568
# ------------------------------
# McNemar Test between custom_GB and NaN_LR
# Chi-squared: 0.10278372591006424
# p-value: 0.7485142871231578
# ------------------------------
# McNemar Test between custom_GB and NaN_MLP
# Chi-squared: 11.789888378200919
# p-value: 0.0005955330588108187
# ------------------------------
# McNemar Test between custom_GB and custom_RF
# Chi-squared: 1610.5872078088878
# p-value: 0.0
# ------------------------------
# McNemar Test between custom_GB and custom_DT
# Chi-squared: 89.03859060402685
# p-value: 3.871853834709337e-21
# ------------------------------
# McNemar Test between custom_GB and custom_XGB
# Chi-squared: 0.002888086642599278
# p-value: 0.957141579257445
# ------------------------------
# McNemar Test between custom_GB and custom_LR
# Chi-squared: 0.01148600143575018
# p-value: 0.9146519217967412
# ------------------------------
# McNemar Test between custom_GB and balanced_DT
# Chi-squared: 70.8051724137931
# p-value: 3.9430193730103513e-17
# ------------------------------
# McNemar Test between custom_GB and balanced_GB
# Chi-squared: 421.8984962406015
# p-value: 9.423631617008787e-94
# ------------------------------
# McNemar Test between custom_GB and balanced_LR
# Chi-squared: 462.8741344195519
# p-value: 1.13876514575986e-102
# ------------------------------
# McNemar Test between custom_GB and balanced_RF
# Chi-squared: 0.37464589235127477
# p-value: 0.5404826858689699
# ------------------------------
# McNemar Test between custom_GB and balanced_XGB
# Chi-squared: 220.7485465116279
# p-value: 6.210230823185919e-50
# ------------------------------
# McNemar Test between custom_GB and oversampling_DT
# Chi-squared: 93.44080044469149
# p-value: 4.1853349353086887e-22
# ------------------------------
# McNemar Test between custom_GB and oversampling_GB
# Chi-squared: 720.102773826458
# p-value: 1.271485056739555e-158
# ------------------------------
# McNemar Test between custom_GB and oversampling_LR
# Chi-squared: 623.3590604026846
# p-value: 1.390518933439098e-137
# ------------------------------
# McNemar Test between custom_GB and oversampling_RF
# Chi-squared: 3.0831043956043955
# p-value: 0.07910939564753781
# ------------------------------
# McNemar Test between custom_GB and oversampling_XGB
# Chi-squared: 888.739603960396
# p-value: 2.7524064943980605e-195
# ------------------------------
# McNemar Test between custom_GB and oversampling_MLP
# Chi-squared: 559.7629144178875
# p-value: 9.466580409899876e-124
# ------------------------------
# McNemar Test between custom_XGB and NaN_RF
# Chi-squared: 0.12106017191977077
# p-value: 0.7278874800949906
# ------------------------------
# McNemar Test between custom_XGB and NaN_DT
# Chi-squared: 94.15886287625418
# p-value: 2.91189899040355e-22
# ------------------------------
# McNemar Test between custom_XGB and NaN_GB
# Chi-squared: 0.000722543352601156
# p-value: 0.9785553126188935
# ------------------------------
# McNemar Test between custom_XGB and NaN_XGB
# Chi-squared: 0.2851033499643621
# p-value: 0.5933756433372119
# ------------------------------
# McNemar Test between custom_XGB and NaN_LR
# Chi-squared: 0.1609442060085837
# p-value: 0.6882886930855607
# ------------------------------
# McNemar Test between custom_XGB and NaN_MLP
# Chi-squared: 12.348026315789474
# p-value: 0.00044145293582150373
# ------------------------------
# McNemar Test between custom_XGB and custom_RF
# Chi-squared: 1615.6938303341901
# p-value: 0.0
# ------------------------------
# McNemar Test between custom_XGB and custom_DT
# Chi-squared: 90.53445378151261
# p-value: 1.81783736162148e-21
# ------------------------------
# McNemar Test between custom_XGB and custom_GB
# Chi-squared: 0.002888086642599278
# p-value: 0.957141579257445
# ------------------------------
# McNemar Test between custom_XGB and custom_LR
# Chi-squared: 0.03525179856115108
# p-value: 0.8510690084428069
# ------------------------------
# McNemar Test between custom_XGB and balanced_DT
# Chi-squared: 72.14507772020725
# p-value: 1.9994382078883048e-17
# ------------------------------
# McNemar Test between custom_XGB and balanced_GB
# Chi-squared: 424.95357590966125
# p-value: 2.0382466574088232e-94
# ------------------------------
# McNemar Test between custom_XGB and balanced_LR
# Chi-squared: 466.0526101141925
# p-value: 2.316099719363363e-103
# ------------------------------
# McNemar Test between custom_XGB and balanced_RF
# Chi-squared: 0.47977288857345635
# p-value: 0.48852520677174827
# ------------------------------
# McNemar Test between custom_XGB and balanced_XGB
# Chi-squared: 223.03930131004367
# p-value: 1.9654167458246947e-50
# ------------------------------
# McNemar Test between custom_XGB and oversampling_DT
# Chi-squared: 94.97160356347439
# p-value: 1.9313596679675731e-22
# ------------------------------
# McNemar Test between custom_XGB and oversampling_GB
# Chi-squared: 723.9145603417586
# p-value: 1.8855978547615379e-159
# ------------------------------
# McNemar Test between custom_XGB and oversampling_LR
# Chi-squared: 626.956326987682
# p-value: 2.295064270650449e-138
# ------------------------------
# McNemar Test between custom_XGB and oversampling_RF
# Chi-squared: 3.372333103922918
# p-value: 0.066299801439001
# ------------------------------
# McNemar Test between custom_XGB and oversampling_XGB
# Chi-squared: 892.8761149653122
# p-value: 3.4711592393288734e-196
# ------------------------------
# McNemar Test between custom_XGB and oversampling_MLP
# Chi-squared: 563.2049401775377
# p-value: 1.6882636290406362e-124
# ------------------------------
# McNemar Test between custom_LR and NaN_RF
# Chi-squared: 0.017806267806267807
# p-value: 0.8938453114675831
# ------------------------------
# McNemar Test between custom_LR and NaN_DT
# Chi-squared: 90.12708102108768
# p-value: 2.2334365283165254e-21
# ------------------------------
# McNemar Test between custom_LR and NaN_GB
# Chi-squared: 0.017959770114942528
# p-value: 0.8933914510349967
# ------------------------------
# McNemar Test between custom_LR and NaN_XGB
# Chi-squared: 0.10205527994330262
# p-value: 0.7493770206992298
# ------------------------------
# McNemar Test between custom_LR and NaN_LR
# Chi-squared: 0.03485064011379801
# p-value: 0.8519089807859275
# ------------------------------
# McNemar Test between custom_LR and NaN_MLP
# Chi-squared: 10.890706806282722
# p-value: 0.0009664794097113525
# ------------------------------
# McNemar Test between custom_LR and custom_RF
# Chi-squared: 1602.103899435608
# p-value: 0.0
# ------------------------------
# McNemar Test between custom_LR and custom_DT
# Chi-squared: 86.57891801450084
# p-value: 1.3427088519326273e-20
# ------------------------------
# McNemar Test between custom_LR and custom_GB
# Chi-squared: 0.01148600143575018
# p-value: 0.9146519217967412
# ------------------------------
# McNemar Test between custom_LR and custom_XGB
# Chi-squared: 0.03525179856115108
# p-value: 0.8510690084428069
# ------------------------------
# McNemar Test between custom_LR and balanced_DT
# Chi-squared: 68.60515759312321
# p-value: 1.2028909738140903e-16
# ------------------------------
# McNemar Test between custom_LR and balanced_GB
# Chi-squared: 416.84035014589415
# p-value: 1.1890155583675883e-92
# ------------------------------
# McNemar Test between custom_LR and balanced_LR
# Chi-squared: 457.61016260162603
# p-value: 1.5920770116034692e-101
# ------------------------------
# McNemar Test between custom_LR and balanced_RF
# Chi-squared: 0.22865208186309105
# p-value: 0.6325250955481914
# ------------------------------
# McNemar Test between custom_LR and balanced_XGB
# Chi-squared: 216.9647172547124
# p-value: 4.154097089557255e-49
# ------------------------------
# McNemar Test between custom_LR and oversampling_DT
# Chi-squared: 90.9229490022173
# p-value: 1.4937709066895834e-21
# ------------------------------
# McNemar Test between custom_LR and oversampling_GB
# Chi-squared: 713.782037628683
# p-value: 3.011277765100421e-157
# ------------------------------
# McNemar Test between custom_LR and oversampling_LR
# Chi-squared: 617.3963528098251
# p-value: 2.754500416158643e-136
# ------------------------------
# McNemar Test between custom_LR and oversampling_RF
# Chi-squared: 2.631074606433949
# p-value: 0.10479076818132682
# ------------------------------
# McNemar Test between custom_LR and oversampling_XGB
# Chi-squared: 881.8767710049424
# p-value: 8.543530003718051e-194
# ------------------------------
# McNemar Test between custom_LR and oversampling_MLP
# Chi-squared: 554.0592535590612
# p-value: 1.6479475520190274e-122
# ------------------------------
# McNemar Test between balanced_DT and NaN_RF
# Chi-squared: 66.01941747572816
# p-value: 4.465024479510059e-16
# ------------------------------
# McNemar Test between balanced_DT and NaN_DT
# Chi-squared: 1.4592833876221498
# p-value: 0.22704417568560456
# ------------------------------
# McNemar Test between balanced_DT and NaN_GB
# Chi-squared: 71.25014376078205
# p-value: 3.146879317816088e-17
# ------------------------------
# McNemar Test between balanced_DT and NaN_XGB
# Chi-squared: 63.07679180887372
# p-value: 1.9880277737575043e-15
# ------------------------------
# McNemar Test between balanced_DT and NaN_LR
# Chi-squared: 65.17056474614945
# p-value: 6.868789029563106e-16
# ------------------------------
# McNemar Test between balanced_DT and NaN_MLP
# Chi-squared: 24.8832
# p-value: 6.091093318984882e-07
# ------------------------------
# McNemar Test between balanced_DT and custom_RF
# Chi-squared: 1090.9550058892814
# p-value: 3.0533031951233646e-239
# ------------------------------
# McNemar Test between balanced_DT and custom_DT
# Chi-squared: 1.0322429906542057
# p-value: 0.30963243530804374
# ------------------------------
# McNemar Test between balanced_DT and custom_GB
# Chi-squared: 70.8051724137931
# p-value: 3.9430193730103513e-17
# ------------------------------
# McNemar Test between balanced_DT and custom_XGB
# Chi-squared: 72.14507772020725
# p-value: 1.9994382078883048e-17
# ------------------------------
# McNemar Test between balanced_DT and custom_LR
# Chi-squared: 68.60515759312321
# p-value: 1.2028909738140903e-16
# ------------------------------
# McNemar Test between balanced_DT and balanced_GB
# Chi-squared: 155.2836853605244
# p-value: 1.21394827802345e-35
# ------------------------------
# McNemar Test between balanced_DT and balanced_LR
# Chi-squared: 181.61596009975062
# p-value: 2.150795823177288e-41
# ------------------------------
# McNemar Test between balanced_DT and balanced_RF
# Chi-squared: 60.61734693877551
# p-value: 6.9320444481762756e-15
# ------------------------------
# McNemar Test between balanced_DT and balanced_XGB
# Chi-squared: 43.18253311258278
# p-value: 4.986384553933915e-11
# ------------------------------
# McNemar Test between balanced_DT and oversampling_DT
# Chi-squared: 1.5639237563923756
# p-value: 0.21109163047004714
# ------------------------------
# McNemar Test between balanced_DT and oversampling_GB
# Chi-squared: 362.5287610619469
# p-value: 7.924261340246491e-81
# ------------------------------
# McNemar Test between balanced_DT and oversampling_LR
# Chi-squared: 291.85266974291363
# p-value: 1.9628210320785987e-65
# ------------------------------
# McNemar Test between balanced_DT and oversampling_RF
# Chi-squared: 44.29701327433628
# p-value: 2.8214636393861247e-11
# ------------------------------
# McNemar Test between balanced_DT and oversampling_XGB
# Chi-squared: 491.2835600236546
# p-value: 7.490741601027616e-109
# ------------------------------
# McNemar Test between balanced_DT and oversampling_MLP
# Chi-squared: 246.98200950441276
# p-value: 1.1814205504232415e-55
# ------------------------------
# McNemar Test between balanced_GB and NaN_RF
# Chi-squared: 410.8257796257796
# p-value: 2.4231254065792547e-91
# ------------------------------
# McNemar Test between balanced_GB and NaN_DT
# Chi-squared: 126.72707813057438
# p-value: 2.131611660860777e-29
# ------------------------------
# McNemar Test between balanced_GB and NaN_GB
# Chi-squared: 422.91516924362725
# p-value: 5.661485067195038e-94
# ------------------------------
# McNemar Test between balanced_GB and NaN_XGB
# Chi-squared: 403.88432835820896
# p-value: 7.8591445348783e-90
# ------------------------------
# McNemar Test between balanced_GB and NaN_LR
# Chi-squared: 408.8342334856668
# p-value: 6.574833661438862e-91
# ------------------------------
# McNemar Test between balanced_GB and NaN_MLP
# Chi-squared: 299.288256227758
# p-value: 4.7080055866514715e-67
# ------------------------------
# McNemar Test between balanced_GB and custom_RF
# Chi-squared: 458.05348030210246
# p-value: 1.2749392791279642e-101
# ------------------------------
# McNemar Test between balanced_GB and custom_DT
# Chi-squared: 131.00393700787401
# p-value: 2.4711567272027086e-30
# ------------------------------
# McNemar Test between balanced_GB and custom_GB
# Chi-squared: 421.8984962406015
# p-value: 9.423631617008787e-94
# ------------------------------
# McNemar Test between balanced_GB and custom_XGB
# Chi-squared: 424.95357590966125
# p-value: 2.0382466574088232e-94
# ------------------------------
# McNemar Test between balanced_GB and custom_LR
# Chi-squared: 416.84035014589415
# p-value: 1.1890155583675883e-92
# ------------------------------
# McNemar Test between balanced_GB and balanced_DT
# Chi-squared: 155.2836853605244
# p-value: 1.21394827802345e-35
# ------------------------------
# McNemar Test between balanced_GB and balanced_LR
# Chi-squared: 1.0401618029471251
# p-value: 0.3077838438135438
# ------------------------------
# McNemar Test between balanced_GB and balanced_RF
# Chi-squared: 397.9987593052109
# p-value: 1.501696927874844e-88
# ------------------------------
# McNemar Test between balanced_GB and balanced_XGB
# Chi-squared: 35.25765472312703
# p-value: 2.888445599625326e-09
# ------------------------------
# McNemar Test between balanced_GB and oversampling_DT
# Chi-squared: 125.78823529411764
# p-value: 3.421096284414422e-29
# ------------------------------
# McNemar Test between balanced_GB and oversampling_GB
# Chi-squared: 45.544525929806184
# p-value: 1.4920809774583804e-11
# ------------------------------
# McNemar Test between balanced_GB and oversampling_LR
# Chi-squared: 22.334327548806943
# p-value: 2.2907490912378687e-06
# ------------------------------
# McNemar Test between balanced_GB and oversampling_RF
# Chi-squared: 356.6080422420796
# p-value: 1.5423487809229858e-79
# ------------------------------
# McNemar Test between balanced_GB and oversampling_XGB
# Chi-squared: 99.90708622398414
# p-value: 1.597167863474207e-23
# ------------------------------
# McNemar Test between balanced_GB and oversampling_MLP
# Chi-squared: 11.000277777777777
# p-value: 0.0009109823375395284
# ------------------------------
# McNemar Test between balanced_LR and NaN_RF
# Chi-squared: 451.3483373884834
# p-value: 3.6701264069664985e-100
# ------------------------------
# McNemar Test between balanced_LR and NaN_DT
# Chi-squared: 150.71543296089385
# p-value: 1.2094433000765364e-34
# ------------------------------
# McNemar Test between balanced_LR and NaN_GB
# Chi-squared: 463.9319478402608
# p-value: 6.702538746938167e-103
# ------------------------------
# McNemar Test between balanced_LR and NaN_XGB
# Chi-squared: 444.11807521229275
# p-value: 1.3746866391324976e-98
# ------------------------------
# McNemar Test between balanced_LR and NaN_LR
# Chi-squared: 449.2743111831442
# p-value: 1.0376379027752485e-99
# ------------------------------
# McNemar Test between balanced_LR and NaN_MLP
# Chi-squared: 334.65675675675675
# p-value: 9.301664917166438e-75
# ------------------------------
# McNemar Test between balanced_LR and custom_RF
# Chi-squared: 416.32439516129034
# p-value: 1.539903155612523e-92
# ------------------------------
# McNemar Test between balanced_LR and custom_DT
# Chi-squared: 155.36112084063046
# p-value: 1.1675577625683338e-35
# ------------------------------
# McNemar Test between balanced_LR and custom_GB
# Chi-squared: 462.8741344195519
# p-value: 1.13876514575986e-102
# ------------------------------
# McNemar Test between balanced_LR and custom_XGB
# Chi-squared: 466.0526101141925
# p-value: 2.316099719363363e-103
# ------------------------------
# McNemar Test between balanced_LR and custom_LR
# Chi-squared: 457.61016260162603
# p-value: 1.5920770116034692e-101
# ------------------------------
# McNemar Test between balanced_LR and balanced_DT
# Chi-squared: 181.61596009975062
# p-value: 2.150795823177288e-41
# ------------------------------
# McNemar Test between balanced_LR and balanced_GB
# Chi-squared: 1.0401618029471251
# p-value: 0.3077838438135438
# ------------------------------
# McNemar Test between balanced_LR and balanced_RF
# Chi-squared: 437.9846712384026
# p-value: 2.972088175754776e-97
# ------------------------------
# McNemar Test between balanced_LR and balanced_XGB
# Chi-squared: 48.578728840626
# p-value: 3.172920615936856e-12
# ------------------------------
# McNemar Test between balanced_LR and oversampling_DT
# Chi-squared: 149.6946964410328
# p-value: 2.0215861933846003e-34
# ------------------------------
# McNemar Test between balanced_LR and oversampling_GB
# Chi-squared: 32.67233823150296
# p-value: 1.0907856884488641e-08
# ------------------------------
# McNemar Test between balanced_LR and oversampling_LR
# Chi-squared: 13.623899706588423
# p-value: 0.00022332432653424802
# ------------------------------
# McNemar Test between balanced_LR and oversampling_RF
# Chi-squared: 394.7697185889814
# p-value: 7.577391088588095e-88
# ------------------------------
# McNemar Test between balanced_LR and oversampling_XGB
# Chi-squared: 80.41884305589456
# p-value: 3.0289301799903116e-19
# ------------------------------
# McNemar Test between balanced_LR and oversampling_MLP
# Chi-squared: 5.201857416006556
# p-value: 0.02256276626470222
# ------------------------------
# McNemar Test between balanced_RF and NaN_RF
# Chi-squared: 0.10119465917076599
# p-value: 0.7504006792929829
# ------------------------------
# McNemar Test between balanced_RF and NaN_DT
# Chi-squared: 80.97528830313014
# p-value: 2.2855797066406433e-19
# ------------------------------
# McNemar Test between balanced_RF and NaN_GB
# Chi-squared: 0.40822111977321046
# p-value: 0.5228737783066646
# ------------------------------
# McNemar Test between balanced_RF and NaN_XGB
# Chi-squared: 0.017482517482517484
# p-value: 0.8948091185487497
# ------------------------------
# McNemar Test between balanced_RF and NaN_LR
# Chi-squared: 0.07017543859649122
# p-value: 0.7910815129207817
# ------------------------------
# McNemar Test between balanced_RF and NaN_MLP
# Chi-squared: 7.821590174531351
# p-value: 0.005162575303065023
# ------------------------------
# McNemar Test between balanced_RF and custom_RF
# Chi-squared: 1570.1812611692621
# p-value: 0.0
# ------------------------------
# McNemar Test between balanced_RF and custom_DT
# Chi-squared: 77.60761589403974
# p-value: 1.2568456516799886e-18
# ------------------------------
# McNemar Test between balanced_RF and custom_GB
# Chi-squared: 0.37464589235127477
# p-value: 0.5404826858689699
# ------------------------------
# McNemar Test between balanced_RF and custom_XGB
# Chi-squared: 0.47977288857345635
# p-value: 0.48852520677174827
# ------------------------------
# McNemar Test between balanced_RF and custom_LR
# Chi-squared: 0.22865208186309105
# p-value: 0.6325250955481914
# ------------------------------
# McNemar Test between balanced_RF and balanced_DT
# Chi-squared: 60.61734693877551
# p-value: 6.9320444481762756e-15
# ------------------------------
# McNemar Test between balanced_RF and balanced_GB
# Chi-squared: 397.9987593052109
# p-value: 1.501696927874844e-88
# ------------------------------
# McNemar Test between balanced_RF and balanced_LR
# Chi-squared: 437.9846712384026
# p-value: 2.972088175754776e-97
# ------------------------------
# McNemar Test between balanced_RF and balanced_XGB
# Chi-squared: 202.9698275862069
# p-value: 4.696478078315056e-46
# ------------------------------
# McNemar Test between balanced_RF and oversampling_DT
# Chi-squared: 81.73121228743828
# p-value: 1.5591167938231785e-19
# ------------------------------
# McNemar Test between balanced_RF and oversampling_GB
# Chi-squared: 690.1272919605077
# p-value: 4.1938324226479994e-152
# ------------------------------
# McNemar Test between balanced_RF and oversampling_LR
# Chi-squared: 595.1075388026608
# p-value: 1.9406869291716144e-131
# ------------------------------
# McNemar Test between balanced_RF and oversampling_RF
# Chi-squared: 1.2493243243243244
# p-value: 0.26368156691385614
# ------------------------------
# McNemar Test between balanced_RF and oversampling_XGB
# Chi-squared: 856.1522593320236
# p-value: 3.342395355209798e-188
# ------------------------------
# McNemar Test between balanced_RF and oversampling_MLP
# Chi-squared: 532.7582123758594
# p-value: 7.0939428004559495e-118
# ------------------------------
# McNemar Test between balanced_XGB and NaN_RF
# Chi-squared: 212.48
# p-value: 3.9519810396450174e-48
# ------------------------------
# McNemar Test between balanced_XGB and NaN_DT
# Chi-squared: 28.61140315406389
# p-value: 8.845971476645048e-08
# ------------------------------
# McNemar Test between balanced_XGB and NaN_GB
# Chi-squared: 221.51042171594764
# p-value: 4.2357186664753737e-50
# ------------------------------
# McNemar Test between balanced_XGB and NaN_XGB
# Chi-squared: 207.32420749279538
# p-value: 5.268237351509359e-47
# ------------------------------
# McNemar Test between balanced_XGB and NaN_LR
# Chi-squared: 210.99855560905152
# p-value: 8.317861390603542e-48
# ------------------------------
# McNemar Test between balanced_XGB and NaN_MLP
# Chi-squared: 132.60572987721693
# p-value: 1.1027448085545879e-30
# ------------------------------
# McNemar Test between balanced_XGB and custom_RF
# Chi-squared: 731.3600350186036
# p-value: 4.533868306505112e-161
# ------------------------------
# McNemar Test between balanced_XGB and custom_DT
# Chi-squared: 30.691964285714285
# p-value: 3.0241486541393214e-08
# ------------------------------
# McNemar Test between balanced_XGB and custom_GB
# Chi-squared: 220.7485465116279
# p-value: 6.210230823185919e-50
# ------------------------------
# McNemar Test between balanced_XGB and custom_XGB
# Chi-squared: 223.03930131004367
# p-value: 1.9654167458246947e-50
# ------------------------------
# McNemar Test between balanced_XGB and custom_LR
# Chi-squared: 216.9647172547124
# p-value: 4.154097089557255e-49
# ------------------------------
# McNemar Test between balanced_XGB and balanced_DT
# Chi-squared: 43.18253311258278
# p-value: 4.986384553933915e-11
# ------------------------------
# McNemar Test between balanced_XGB and balanced_GB
# Chi-squared: 35.25765472312703
# p-value: 2.888445599625326e-09
# ------------------------------
# McNemar Test between balanced_XGB and balanced_LR
# Chi-squared: 48.578728840626
# p-value: 3.172920615936856e-12
# ------------------------------
# McNemar Test between balanced_XGB and balanced_RF
# Chi-squared: 202.9698275862069
# p-value: 4.696478078315056e-46
# ------------------------------
# McNemar Test between balanced_XGB and oversampling_DT
# Chi-squared: 28.16
# p-value: 1.116891048913363e-07
# ------------------------------
# McNemar Test between balanced_XGB and oversampling_GB
# Chi-squared: 159.97964449541286
# p-value: 1.1431303907002819e-36
# ------------------------------
# McNemar Test between balanced_XGB and oversampling_LR
# Chi-squared: 113.36777843954735
# p-value: 1.7924420075049598e-26
# ------------------------------
# McNemar Test between balanced_XGB and oversampling_RF
# Chi-squared: 172.81848030018762
# p-value: 1.793127350237391e-39
# ------------------------------
# McNemar Test between balanced_XGB and oversampling_XGB
# Chi-squared: 251.27495952509443
# p-value: 1.369272161236135e-56
# ------------------------------
# McNemar Test between balanced_XGB and oversampling_MLP
# Chi-squared: 85.5782874617737
# p-value: 2.2270747189613403e-20
# ------------------------------
# McNemar Test between oversampling_DT and NaN_RF
# Chi-squared: 87.95635359116022
# p-value: 6.69148309130248e-21
# ------------------------------
# McNemar Test between oversampling_DT and NaN_DT
# Chi-squared: 0.0004528985507246377
# p-value: 0.9830211705448397
# ------------------------------
# McNemar Test between oversampling_DT and NaN_GB
# Chi-squared: 93.94938820912125
# p-value: 3.236957518697418e-22
# ------------------------------
# McNemar Test between oversampling_DT and NaN_XGB
# Chi-squared: 84.57017061089708
# p-value: 3.7081778514413563e-20
# ------------------------------
# McNemar Test between oversampling_DT and NaN_LR
# Chi-squared: 86.98068432671081
# p-value: 1.0958623602663131e-20
# ------------------------------
# McNemar Test between oversampling_DT and NaN_MLP
# Chi-squared: 39.1028955532575
# p-value: 4.0204727039635224e-10
# ------------------------------
# McNemar Test between oversampling_DT and custom_RF
# Chi-squared: 1017.808782527881
# p-value: 2.4171987984085717e-223
# ------------------------------
# McNemar Test between oversampling_DT and custom_DT
# Chi-squared: 0.04547521600727603
# p-value: 0.8311326043402728
# ------------------------------
# McNemar Test between oversampling_DT and custom_GB
# Chi-squared: 93.44080044469149
# p-value: 4.1853349353086887e-22
# ------------------------------
# McNemar Test between oversampling_DT and custom_XGB
# Chi-squared: 94.97160356347439
# p-value: 1.9313596679675731e-22
# ------------------------------
# ...
# ------------------------------
# McNemar Test between oversampling_DT and oversampling_LR
# Chi-squared: 251.51115421920466
# p-value: 1.2161813097206215e-56
# ------------------------------
# McNemar Test between oversampling_DT and oversampling_RF
# Chi-squared: 62.648098553829676
# p-value: 2.4714344989469606e-15
# ------------------------------
# McNemar Test between oversampling_DT and oversampling_XGB
# Chi-squared: 439.66870095902357
# p-value: 1.2780555135862282e-97
# ------------------------------
# McNemar Test between oversampling_DT and oversampling_MLP
# Chi-squared: 209.7956738768719
# p-value: 1.5221031155527425e-47
# ------------------------------
# McNemar Test between oversampling_GB and NaN_RF
# Chi-squared: 706.2500885582714
# p-value: 1.3079462080179961e-155
# ------------------------------
# McNemar Test between oversampling_GB and NaN_DT
# Chi-squared: 319.2163924247128
# p-value: 2.1457967316027103e-71
# ------------------------------
# McNemar Test between oversampling_GB and NaN_GB
# Chi-squared: 721.3717538242619
# p-value: 6.735572019622952e-159
# ------------------------------
# McNemar Test between oversampling_GB and NaN_XGB
# Chi-squared: 697.535335689046
# p-value: 1.0272187707905863e-153
# ------------------------------
# McNemar Test between oversampling_GB and NaN_LR
# Chi-squared: 703.7522123893805
# p-value: 4.568398762128067e-155
# ------------------------------
# McNemar Test between oversampling_GB and NaN_MLP
# Chi-squared: 562.9263657957245
# p-value: 1.9410600768126947e-124
# ------------------------------
# McNemar Test between oversampling_GB and custom_RF
# Chi-squared: 219.37182621779198
# p-value: 1.239952879818738e-49
# ------------------------------
# McNemar Test between oversampling_GB and custom_DT
# Chi-squared: 325.81849315068496
# p-value: 7.826047862292384e-73
# ------------------------------
# McNemar Test between oversampling_GB and custom_GB
# Chi-squared: 720.102773826458
# p-value: 1.271485056739555e-158
# ------------------------------
# McNemar Test between oversampling_GB and custom_XGB
# Chi-squared: 723.9145603417586
# p-value: 1.8855978547615379e-159
# ------------------------------
# McNemar Test between oversampling_GB and custom_LR
# Chi-squared: 713.782037628683
# p-value: 3.011277765100421e-157
# ------------------------------
# McNemar Test between oversampling_GB and balanced_DT
# Chi-squared: 362.5287610619469
# p-value: 7.924261340246491e-81
# ------------------------------
# McNemar Test between oversampling_GB and balanced_GB
# Chi-squared: 45.544525929806184
# p-value: 1.4920809774583804e-11
# ------------------------------
# McNemar Test between oversampling_GB and balanced_LR
# Chi-squared: 32.67233823150296
# p-value: 1.0907856884488641e-08
# ------------------------------
# McNemar Test between oversampling_GB and balanced_RF
# Chi-squared: 690.1272919605077
# p-value: 4.1938324226479994e-152
# ------------------------------
# McNemar Test between oversampling_GB and balanced_XGB
# Chi-squared: 159.97964449541286
# p-value: 1.1431303907002819e-36
# ------------------------------
# McNemar Test between oversampling_GB and oversampling_DT
# Chi-squared: 317.76109215017067
# p-value: 4.452348148592599e-71
# ------------------------------
# McNemar Test between oversampling_GB and oversampling_LR
# Chi-squared: 4.052849488553337
# p-value: 0.044096851567754544
# ------------------------------
# McNemar Test between oversampling_GB and oversampling_RF
# Chi-squared: 637.5086805555555
# p-value: 1.1635026020317048e-140
# ------------------------------
# McNemar Test between oversampling_GB and oversampling_XGB
# Chi-squared: 10.572294566681634
# p-value: 0.001147951477903789
# ------------------------------
# McNemar Test between oversampling_GB and oversampling_MLP
# Chi-squared: 11.71951219512195
# p-value: 0.0006184816465136642
# ------------------------------
# McNemar Test between oversampling_LR and NaN_RF
# Chi-squared: 610.2948384701077
# p-value: 9.65208526499904e-135
# ------------------------------
# McNemar Test between oversampling_LR and NaN_DT
# Chi-squared: 252.81656421869945
# p-value: 6.315631061486563e-57
# ------------------------------
# McNemar Test between oversampling_LR and NaN_GB
# Chi-squared: 624.5565087653861
# p-value: 7.63376686478644e-138
# ------------------------------
# McNemar Test between oversampling_LR and NaN_XGB
# Chi-squared: 602.0833333333334
# p-value: 5.897375127475112e-133
# ------------------------------
# McNemar Test between oversampling_LR and NaN_LR
# Chi-squared: 607.9406307977737
# p-value: 3.1381043484618757e-134
# ------------------------------
# McNemar Test between oversampling_LR and NaN_MLP
# Chi-squared: 476.0255591054313
# p-value: 1.5652386075709854e-105
# ------------------------------
# McNemar Test between oversampling_LR and custom_RF
# Chi-squared: 282.2633506844033
# p-value: 2.412013715061194e-63
# ------------------------------
# McNemar Test between oversampling_LR and custom_DT
# Chi-squared: 258.74399740428294
# p-value: 3.223273929039713e-58
# ------------------------------
# McNemar Test between oversampling_LR and custom_GB
# Chi-squared: 623.3590604026846
# p-value: 1.390518933439098e-137
# ------------------------------
# McNemar Test between oversampling_LR and custom_XGB
# Chi-squared: 626.956326987682
# p-value: 2.295064270650449e-138
# ------------------------------
# McNemar Test between oversampling_LR and custom_LR
# Chi-squared: 617.3963528098251
# p-value: 2.754500416158643e-136
# ------------------------------
# McNemar Test between oversampling_LR and balanced_DT
# Chi-squared: 291.85266974291363
# p-value: 1.9628210320785987e-65
# ------------------------------
# McNemar Test between oversampling_LR and balanced_GB
# Chi-squared: 22.334327548806943
# p-value: 2.2907490912378687e-06
# ------------------------------
# McNemar Test between oversampling_LR and balanced_LR
# Chi-squared: 13.623899706588423
# p-value: 0.00022332432653424802
# ------------------------------
# McNemar Test between oversampling_LR and balanced_RF
# Chi-squared: 595.1075388026608
# p-value: 1.9406869291716144e-131
# ------------------------------
# McNemar Test between oversampling_LR and balanced_XGB
# Chi-squared: 113.36777843954735
# p-value: 1.7924420075049598e-26
# ------------------------------
# McNemar Test between oversampling_LR and oversampling_DT
# Chi-squared: 251.51115421920466
# p-value: 1.2161813097206215e-56
# ------------------------------
# McNemar Test between oversampling_LR and oversampling_GB
# Chi-squared: 4.052849488553337
# p-value: 0.044096851567754544
# ------------------------------
# McNemar Test between oversampling_LR and oversampling_RF
# Chi-squared: 545.6818181818181
# p-value: 1.0949059171604066e-120
# ------------------------------
# McNemar Test between oversampling_LR and oversampling_XGB
# Chi-squared: 27.846669750231268
# p-value: 1.313199077709546e-07
# ------------------------------
# McNemar Test between oversampling_LR and oversampling_MLP
# Chi-squared: 1.9467592592592593
# p-value: 0.1629364998446533
# ------------------------------
# McNemar Test between oversampling_RF and NaN_RF
# Chi-squared: 2.137695978186776
# p-value: 0.14371759718504554
# ------------------------------
# McNemar Test between oversampling_RF and NaN_DT
# Chi-squared: 61.983914209115284
# p-value: 3.4627442169383385e-15
# ------------------------------
# McNemar Test between oversampling_RF and NaN_GB
# Chi-squared: 3.1780068728522335
# p-value: 0.07463571858375133
# ------------------------------
# McNemar Test between oversampling_RF and NaN_XGB
# Chi-squared: 1.6289009497964722
# p-value: 0.20185513004190622
# ------------------------------
# McNemar Test between oversampling_RF and NaN_LR
# Chi-squared: 1.9850238257317903
# p-value: 0.1588621561077428
# ------------------------------
# McNemar Test between oversampling_RF and NaN_MLP
# Chi-squared: 2.7379006913890636
# p-value: 0.09799342540934892
# ------------------------------
# McNemar Test between oversampling_RF and custom_RF
# Chi-squared: 1498.130775056804
# p-value: 0.0
# ------------------------------
# McNemar Test between oversampling_RF and custom_DT
# Chi-squared: 59.030711206896555
# p-value: 1.5523018277069523e-14
# ------------------------------
# McNemar Test between oversampling_RF and custom_GB
# Chi-squared: 3.0831043956043955
# p-value: 0.07910939564753781
# ------------------------------
# McNemar Test between oversampling_RF and custom_XGB
# Chi-squared: 3.372333103922918
# p-value: 0.066299801439001
# ------------------------------
# McNemar Test between oversampling_RF and custom_LR
# Chi-squared: 2.631074606433949
# p-value: 0.10479076818132682
# ------------------------------
# McNemar Test between oversampling_RF and balanced_DT
# Chi-squared: 44.29701327433628
# p-value: 2.8214636393861247e-11
# ------------------------------
# McNemar Test between oversampling_RF and balanced_GB
# Chi-squared: 356.6080422420796
# p-value: 1.5423487809229858e-79
# ------------------------------
# McNemar Test between oversampling_RF and balanced_LR
# Chi-squared: 394.7697185889814
# p-value: 7.577391088588095e-88
# ------------------------------
# McNemar Test between oversampling_RF and balanced_RF
# Chi-squared: 1.2493243243243244
# p-value: 0.26368156691385614
# ------------------------------
# McNemar Test between oversampling_RF and balanced_XGB
# Chi-squared: 172.81848030018762
# p-value: 1.793127350237391e-39
# ------------------------------
# McNemar Test between oversampling_RF and oversampling_DT
# Chi-squared: 62.648098553829676
# p-value: 2.4714344989469606e-15
# ------------------------------
# McNemar Test between oversampling_RF and oversampling_GB
# Chi-squared: 637.5086805555555
# p-value: 1.1635026020317048e-140
# ------------------------------
# McNemar Test between oversampling_RF and oversampling_LR
# Chi-squared: 545.6818181818181
# p-value: 1.0949059171604066e-120
# ------------------------------
# McNemar Test between oversampling_RF and oversampling_XGB
# Chi-squared: 798.6859264041317
# p-value: 1.041752785497522e-175
# ------------------------------
# McNemar Test between oversampling_RF and oversampling_MLP
# Chi-squared: 485.6382419233659
# p-value: 1.2673295751041154e-107
# ------------------------------
# McNemar Test between oversampling_XGB and NaN_RF
# Chi-squared: 873.6928641894114
# p-value: 5.137716126256608e-192
# ------------------------------
# McNemar Test between oversampling_XGB and NaN_DT
# Chi-squared: 441.3562082000582
# p-value: 5.48635703264321e-98
# ------------------------------
# McNemar Test between oversampling_XGB and NaN_GB
# Chi-squared: 890.1168702542093
# p-value: 1.3813619870575665e-195
# ------------------------------
# McNemar Test between oversampling_XGB and NaN_XGB
# Chi-squared: 864.2155511811023
# p-value: 5.90344350864916e-190
# ------------------------------
# McNemar Test between oversampling_XGB and NaN_LR
# Chi-squared: 870.9773250082155
# p-value: 2.0003978284497796e-191
# ------------------------------
# McNemar Test between oversampling_XGB and NaN_MLP
# Chi-squared: 716.5990521327014
# p-value: 7.34836902857545e-158
# ------------------------------
# McNemar Test between oversampling_XGB and custom_RF
# Chi-squared: 134.2446251129178
# p-value: 4.830195372502038e-31
# ------------------------------
# McNemar Test between oversampling_XGB and custom_DT
# Chi-squared: 449.00320699708453
# p-value: 1.188627703020457e-99
# ------------------------------
# McNemar Test between oversampling_XGB and custom_GB
# Chi-squared: 888.739603960396
# p-value: 2.7524064943980605e-195
# ------------------------------
# McNemar Test between oversampling_XGB and custom_XGB
# Chi-squared: 892.8761149653122
# p-value: 3.4711592393288734e-196
# ------------------------------
# McNemar Test between oversampling_XGB and custom_LR
# Chi-squared: 881.8767710049424
# p-value: 8.543530003718051e-194
# ------------------------------
# McNemar Test between oversampling_XGB and balanced_DT
# Chi-squared: 491.2835600236546
# p-value: 7.490741601027616e-109
# ------------------------------
# McNemar Test between oversampling_XGB and balanced_GB
# Chi-squared: 99.90708622398414
# p-value: 1.597167863474207e-23
# ------------------------------
# McNemar Test between oversampling_XGB and balanced_LR
# Chi-squared: 80.41884305589456
# p-value: 3.0289301799903116e-19
# ------------------------------
# McNemar Test between oversampling_XGB and balanced_RF
# Chi-squared: 856.1522593320236
# p-value: 3.342395355209798e-188
# ------------------------------
# McNemar Test between oversampling_XGB and balanced_XGB
# Chi-squared: 251.27495952509443
# p-value: 1.369272161236135e-56
# ------------------------------
# McNemar Test between oversampling_XGB and oversampling_DT
# Chi-squared: 439.66870095902357
# p-value: 1.2780555135862282e-97
# ------------------------------
# McNemar Test between oversampling_XGB and oversampling_GB
# Chi-squared: 10.572294566681634
# p-value: 0.001147951477903789
# ------------------------------
# McNemar Test between oversampling_XGB and oversampling_LR
# Chi-squared: 27.846669750231268
# p-value: 1.313199077709546e-07
# ------------------------------
# McNemar Test between oversampling_XGB and oversampling_RF
# Chi-squared: 798.6859264041317
# p-value: 1.041752785497522e-175
# ------------------------------
# McNemar Test between oversampling_XGB and oversampling_MLP
# Chi-squared: 44.670679886685555
# p-value: 2.331222834902113e-11
# ------------------------------
# McNemar Test between oversampling_MLP and NaN_RF
# Chi-squared: 547.2690978886757
# p-value: 4.943960134272382e-121
# ------------------------------
# McNemar Test between oversampling_MLP and NaN_DT
# Chi-squared: 210.994338994339
# p-value: 8.335499015950147e-48
# ------------------------------
# McNemar Test between oversampling_MLP and NaN_GB
# Chi-squared: 560.9086000771307
# p-value: 5.332958826090104e-124
# ------------------------------
# McNemar Test between oversampling_MLP and NaN_XGB
# Chi-squared: 539.4215160796325
# p-value: 2.5193040704082326e-119
# ------------------------------
# McNemar Test between oversampling_MLP and NaN_LR
# Chi-squared: 545.0187955504412
# p-value: 1.526206786724482e-120
# ------------------------------
# McNemar Test between oversampling_MLP and NaN_MLP
# Chi-squared: 419.53096372297546
# p-value: 3.0870075545316406e-93
# ------------------------------
# McNemar Test between oversampling_MLP and custom_RF
# Chi-squared: 330.4185134340067
# p-value: 7.791745268651168e-74
# ------------------------------
# McNemar Test between oversampling_MLP and custom_DT
# Chi-squared: 216.44121576486305
# p-value: 5.403478010395484e-49
# ------------------------------
# McNemar Test between oversampling_MLP and custom_GB
# Chi-squared: 559.7629144178875
# p-value: 9.466580409899876e-124
# ------------------------------
# McNemar Test between oversampling_MLP and custom_XGB
# Chi-squared: 563.2049401775377
# p-value: 1.6882636290406362e-124
# ------------------------------
# McNemar Test between oversampling_MLP and custom_LR
# Chi-squared: 554.0592535590612
# p-value: 1.6479475520190274e-122
# ------------------------------
# McNemar Test between oversampling_MLP and balanced_DT
# Chi-squared: 246.98200950441276
# p-value: 1.1814205504232415e-55
# ------------------------------
# McNemar Test between oversampling_MLP and balanced_GB
# Chi-squared: 11.000277777777777
# p-value: 0.0009109823375395284
# ------------------------------
# McNemar Test between oversampling_MLP and balanced_LR
# Chi-squared: 5.201857416006556
# p-value: 0.02256276626470222
# ------------------------------
# McNemar Test between oversampling_MLP and balanced_RF
# Chi-squared: 532.7582123758594
# p-value: 7.0939428004559495e-118
# ------------------------------
# McNemar Test between oversampling_MLP and balanced_XGB
# Chi-squared: 85.5782874617737
# p-value: 2.2270747189613403e-20
# ------------------------------
# McNemar Test between oversampling_MLP and oversampling_DT
# Chi-squared: 209.7956738768719
# p-value: 1.5221031155527425e-47
# ------------------------------
# McNemar Test between oversampling_MLP and oversampling_GB
# Chi-squared: 11.71951219512195
# p-value: 0.0006184816465136642
# ------------------------------
# McNemar Test between oversampling_MLP and oversampling_LR
# Chi-squared: 1.9467592592592593
# p-value: 0.1629364998446533
# ------------------------------
# McNemar Test between oversampling_MLP and oversampling_RF
# Chi-squared: 485.6382419233659
# p-value: 1.2673295751041154e-107
# ------------------------------
# McNemar Test between oversampling_MLP and oversampling_XGB
# Chi-squared: 44.670679886685555
# p-value: 2.331222834902113e-11
# ------------------------------

# %% [markdown]
# ##### 2. Multiclass Classifiers:

# %%
import numpy as np
from mlxtend.evaluate import mcnemar

# Multiclass classifier confusion matrices
confusion_matrices = {
    # Confusion matrices for each NaN classifier
    "NaN_rf": np.array([[65, 94, 39], [57, 109, 98], [22, 82, 120]]),
    "NaN_dt": np.array([[72, 77, 49], [81, 104, 79], [54, 70, 100]]),
    "NaN_gb": np.array([[57, 88, 53], [45, 116, 103], [15, 68, 141]]),
    "NaN_xgb": np.array([[65, 89, 44], [62, 118, 84], [31, 77, 116]]),
    "NaN_lr": np.array([[50, 96, 52], [48, 117, 99], [26, 65, 133]]),
    "NaN_mlp": np.array([[76, 78, 44], [63, 106, 95], [43, 71, 110]]),
    # Confusion matrices for each custom weight technique classifier
    "custom_rf": np.array([[66, 95, 37], [62, 121, 81], [28, 69, 127]]),
    "custom_dt": np.array([[59, 83, 56], [81, 99, 84], [44, 70, 110]]),
    "custom_gb": np.array([[91, 49, 58], [87, 70, 107], [27, 48, 149]]),
    "custom_xgb": np.array([[81, 82, 35], [81, 97, 86], [35, 67, 122]]),
    "custom_lr": np.array([[89, 52, 57], [83, 68, 113], [41, 43, 140]]),
    # Confusion matrices for each oversample classifier
    "oversampling_rf": np.array([[91, 64, 43], [73, 100, 91], [33, 68, 123]]),
    "oversampling_dt": np.array([[80, 70, 48], [88, 98, 78], [44, 79, 101]]),
    "oversampling_gb": np.array([[94, 41, 63], [92, 59, 113], [29, 42, 153]]),
    "oversampling_xgb": np.array([[73, 73, 52], [87, 76, 101], [34, 69, 121]]),
    "oversampling_lr": np.array([[90, 50, 58], [89, 65, 110], [45, 42, 137]]),
    "oversampling_lr": np.array([[99, 67, 32], [97, 87, 80], [63, 74, 87]]),
}


def get_binary_table(matrix1, matrix2, class1, class2):
    table = np.zeros((2, 2), dtype=int)
    for i in range(3):
        for j in range(3):
            if i == class1 and j == class1:
                table[0, 0] += matrix1[i, j]
                table[0, 0] += matrix2[i, j]
            elif i == class1 and j == class2:
                table[0, 1] += matrix1[i, j]
                table[0, 1] += matrix2[i, j]
            elif i == class2 and j == class1:
                table[1, 0] += matrix1[i, j]
                table[1, 0] += matrix2[i, j]
            elif i == class2 and j == class2:
                table[1, 1] += matrix1[i, j]
                table[1, 1] += matrix2[i, j]
    return table


def mcnemar_test_for_pair(matrix1, matrix2):
    classes = [0, 1, 2]
    results = {}

    for i in range(len(classes)):
        for j in range(i + 1, len(classes)):
            tb_b = get_binary_table(matrix1, matrix2, classes[i], classes[j])

            chi2, p = mcnemar(ary=tb_b, corrected=True)
            results[f"Class {classes[i]} vs Class {classes[j]}"] = {
                "chi-squared": chi2,
                "p-value": p,
            }

    return results


classifiers = list(confusion_matrices.keys())
all_results = {}

for i in range(len(classifiers)):
    for j in range(i + 1, len(classifiers)):
        key = f"{classifiers[i]} vs {classifiers[j]}"
        all_results[key] = mcnemar_test_for_pair(
            confusion_matrices[classifiers[i]], confusion_matrices[classifiers[j]]
        )

# Print all results
for pair, results in all_results.items():
    print(f"\nResults for {pair}:")
    for class_pair, result in results.items():
        print(
            f'{class_pair} - chi-squared: {result["chi-squared"]}, p-value: {result["p-value"]}'
        )
# Out:
# Results for NaN_rf vs NaN_dt:
# Class 0 vs Class 1 - chi-squared: 3.313915857605178, p-value: 0.0686956172900934
# Class 0 vs Class 2 - chi-squared: 0.7378048780487805, p-value: 0.39036496254880615
# Class 1 vs Class 2 - chi-squared: 1.750759878419453, p-value: 0.1857812335807854
#
# Results for NaN_rf vs NaN_gb:
# Class 0 vs Class 1 - chi-squared: 21.975352112676056, p-value: 2.7617449828327876e-06
# Class 0 vs Class 2 - chi-squared: 22.6046511627907, p-value: 1.9900225604473457e-06
# Class 1 vs Class 2 - chi-squared: 7.122507122507122, p-value: 0.007612218247778954
#
# Results for NaN_rf vs NaN_xgb:
# Class 0 vs Class 1 - chi-squared: 13.142384105960264, p-value: 0.0002886902839849097
# Class 0 vs Class 2 - chi-squared: 6.1838235294117645, p-value: 0.012892338994381351
# Class 1 vs Class 2 - chi-squared: 1.4193548387096775, p-value: 0.23350962263557928
#
# Results for NaN_rf vs NaN_lr:
# Class 0 vs Class 1 - chi-squared: 23.91864406779661, p-value: 1.004937915095615e-06
# Class 0 vs Class 2 - chi-squared: 12.690647482014388, p-value: 0.000367488998715786
# Class 1 vs Class 2 - chi-squared: 6.979651162790698, p-value: 0.008244167680551787
#
# Results for NaN_rf vs NaN_mlp:
# Class 0 vs Class 1 - chi-squared: 8.907534246575343, p-value: 0.0028399647548386967
# Class 0 vs Class 2 - chi-squared: 1.9527027027027026, p-value: 0.16229590623696744
# Class 1 vs Class 2 - chi-squared: 4.395953757225434, p-value: 0.03602430486423832
#
# Results for NaN_rf vs custom_rf:
# Class 0 vs Class 1 - chi-squared: 15.457792207792208, p-value: 8.436838033074959e-05
# Class 0 vs Class 2 - chi-squared: 4.9603174603174605, p-value: 0.025935445587354288
# Class 1 vs Class 2 - chi-squared: 2.209090909090909, p-value: 0.13719950041496204
#
# Results for NaN_rf vs custom_dt:
# Class 0 vs Class 1 - chi-squared: 4.584126984126984, p-value: 0.03226940582274831
# Class 0 vs Class 2 - chi-squared: 4.869565217391305, p-value: 0.02733438646050386
# Class 1 vs Class 2 - chi-squared: 2.5179640718562872, p-value: 0.1125558192309511
#
# Results for NaN_rf vs custom_gb:
# Class 0 vs Class 1 - chi-squared: 0.0, p-value: 1.0
# Class 0 vs Class 2 - chi-squared: 15.13013698630137, p-value: 0.00010034850589288473
# Class 1 vs Class 2 - chi-squared: 16.34626865671642, p-value: 5.275993652789928e-05
#
# Results for NaN_rf vs custom_xgb:
# Class 0 vs Class 1 - chi-squared: 4.359872611464968, p-value: 0.036795056661533036
# Class 0 vs Class 2 - chi-squared: 1.9541984732824427, p-value: 0.1621351427341069
# Class 1 vs Class 2 - chi-squared: 3.4714714714714714, p-value: 0.06243574707022045
#
# Results for NaN_rf vs custom_lr:
# Class 0 vs Class 1 - chi-squared: 0.08741258741258741, p-value: 0.7674926513236701
# Class 0 vs Class 2 - chi-squared: 6.440251572327044, p-value: 0.011156284589967447
# Class 1 vs Class 2 - chi-squared: 21.50297619047619, p-value: 3.532799468984277e-06
#
# Results for NaN_rf vs oversampling_rf:
# Class 0 vs Class 1 - chi-squared: 2.53125, p-value: 0.11161176829829161
# Class 0 vs Class 2 - chi-squared: 4.934306569343065, p-value: 0.026328624450893096
# Class 1 vs Class 2 - chi-squared: 4.259587020648968, p-value: 0.03902940870837655
#
# Results for NaN_rf vs oversampling_dt:
# Class 0 vs Class 1 - chi-squared: 1.0485436893203883, p-value: 0.30584272681948044
# Class 0 vs Class 2 - chi-squared: 2.6143790849673203, p-value: 0.1058989688236934
# Class 1 vs Class 2 - chi-squared: 0.5816023738872403, p-value: 0.44568492607134347
#
# Results for NaN_rf vs oversampling_gb:
# Class 0 vs Class 1 - chi-squared: 0.5950704225352113, p-value: 0.44046508860298905
# Class 0 vs Class 2 - chi-squared: 16.33986928104575, p-value: 5.2938391535725534e-05
# Class 1 vs Class 2 - chi-squared: 22.077611940298507, p-value: 2.618458690123567e-06
#
# Results for NaN_rf vs oversampling_xgb:
# Class 0 vs Class 1 - chi-squared: 1.5562700964630225, p-value: 0.21221218662377095
# Class 0 vs Class 2 - chi-squared: 7.863945578231292, p-value: 0.005043022603806805
# Class 1 vs Class 2 - chi-squared: 6.311428571428571, p-value: 0.011996214124703947
#
# Results for NaN_rf vs oversampling_lr:
# Class 0 vs Class 1 - chi-squared: 0.11428571428571428, p-value: 0.7353166906373405
# Class 0 vs Class 2 - chi-squared: 1.0833333333333333, p-value: 0.29795306160816476
# Class 1 vs Class 2 - chi-squared: 1.3203592814371257, p-value: 0.2505275810871858
#
# Results for NaN_dt vs NaN_gb:
# Class 0 vs Class 1 - chi-squared: 4.962199312714777, p-value: 0.02590723733673028
# Class 0 vs Class 2 - chi-squared: 5.988304093567251, p-value: 0.014401041270461006
# Class 1 vs Class 2 - chi-squared: 5.778125, p-value: 0.01622684256784749
#
# Results for NaN_dt vs NaN_xgb:
# Class 0 vs Class 1 - chi-squared: 1.5663430420711975, p-value: 0.21073888842031338
# Class 0 vs Class 2 - chi-squared: 0.2752808988764045, p-value: 0.5998110984392087
# Class 1 vs Class 2 - chi-squared: 0.7258064516129032, p-value: 0.39424586721077726
#
# Results for NaN_dt vs NaN_lr:
# Class 0 vs Class 1 - chi-squared: 6.122516556291391, p-value: 0.013347065700337057
# Class 0 vs Class 2 - chi-squared: 2.2099447513812156, p-value: 0.13712358179944215
# Class 1 vs Class 2 - chi-squared: 5.635782747603834, p-value: 0.017597486510815816
#
# Results for NaN_dt vs NaN_mlp:
# Class 0 vs Class 1 - chi-squared: 0.33444816053511706, p-value: 0.5630515150259174
# Class 0 vs Class 2 - chi-squared: 0.04736842105263158, p-value: 0.8277073757089304
# Class 1 vs Class 2 - chi-squared: 3.250793650793651, p-value: 0.07138888317232228
#
# Results for NaN_dt vs custom_rf:
# Class 0 vs Class 1 - chi-squared: 2.488888888888889, p-value: 0.1146526416844945
# Class 0 vs Class 2 - chi-squared: 0.05357142857142857, p-value: 0.8169613217153913
# Class 1 vs Class 2 - chi-squared: 1.3377926421404682, p-value: 0.24742361561897902
#
# Results for NaN_dt vs custom_dt:
# Class 0 vs Class 1 - chi-squared: 0.003105590062111801, p-value: 0.955558635777595
# Class 0 vs Class 2 - chi-squared: 0.17733990147783252, p-value: 0.6736693243745802
# Class 1 vs Class 2 - chi-squared: 1.5973597359735974, p-value: 0.20627777630398905
#
# Results for NaN_dt vs custom_gb:
# Class 0 vs Class 1 - chi-squared: 5.717687074829932, p-value: 0.016794840323876438
# Class 0 vs Class 2 - chi-squared: 3.324468085106383, p-value: 0.0682560902568442
# Class 1 vs Class 2 - chi-squared: 14.766447368421053, p-value: 0.00012168146217711314
#
# Results for NaN_dt vs custom_xgb:
# Class 0 vs Class 1 - chi-squared: 0.012461059190031152, p-value: 0.9111174863108885
# Class 0 vs Class 2 - chi-squared: 0.09248554913294797, p-value: 0.761040760480224
# Class 1 vs Class 2 - chi-squared: 2.4139072847682117, p-value: 0.1202618610556607
#
# Results for NaN_dt vs custom_lr:
# Class 0 vs Class 1 - chi-squared: 3.945392491467577, p-value: 0.04699988852784433
# Class 0 vs Class 2 - chi-squared: 0.4975124378109453, p-value: 0.4805951793536507
# Class 1 vs Class 2 - chi-squared: 19.947540983606558, p-value: 7.959625913574113e-06
#
# Results for NaN_dt vs oversampling_rf:
# Class 0 vs Class 1 - chi-squared: 0.488135593220339, p-value: 0.48476015438928843
# Class 0 vs Class 2 - chi-squared: 0.0893854748603352, p-value: 0.7649598554295175
# Class 1 vs Class 2 - chi-squared: 3.1201298701298703, p-value: 0.07733062015390492
#
# Results for NaN_dt vs oversampling_dt:
# Class 0 vs Class 1 - chi-squared: 1.3955696202531647, p-value: 0.23746677131689994
# Class 0 vs Class 2 - chi-squared: 0.0, p-value: 1.0
# Class 1 vs Class 2 - chi-squared: 0.16013071895424835, p-value: 0.6890361955633366
#
# Results for NaN_dt vs oversampling_gb:
# Class 0 vs Class 1 - chi-squared: 10.02061855670103, p-value: 0.00154797472541152
# Class 0 vs Class 2 - chi-squared: 4.02051282051282, p-value: 0.044950043775533646
# Class 1 vs Class 2 - chi-squared: 20.529605263157894, p-value: 5.871604948173517e-06
#
# Results for NaN_dt vs oversampling_xgb:
# Class 0 vs Class 1 - chi-squared: 0.9088050314465409, p-value: 0.34043167794644535
# Class 0 vs Class 2 - chi-squared: 0.7619047619047619, p-value: 0.38273308888522595
# Class 1 vs Class 2 - chi-squared: 5.015673981191223, p-value: 0.025118849300285538
#
# Results for NaN_dt vs oversampling_lr:
# Class 0 vs Class 1 - chi-squared: 3.3819875776397517, p-value: 0.06591252367502211
# Class 0 vs Class 2 - chi-squared: 6.186868686868687, p-value: 0.01287017198864741
# Class 1 vs Class 2 - chi-squared: 0.6468646864686468, p-value: 0.42123587132119644
#
# Results for NaN_gb vs NaN_xgb:
# Class 0 vs Class 1 - chi-squared: 16.764084507042252, p-value: 4.232690332993706e-05
# Class 0 vs Class 2 - chi-squared: 17.482517482517483, p-value: 2.8996184057874947e-05
# Class 1 vs Class 2 - chi-squared: 5.063253012048193, p-value: 0.024438325330965936
#
# Results for NaN_gb vs NaN_lr:
# Class 0 vs Class 1 - chi-squared: 29.24187725631769, p-value: 6.388346887724875e-08
# Class 0 vs Class 2 - chi-squared: 27.184931506849313, p-value: 1.8489412360684014e-07
# Class 1 vs Class 2 - chi-squared: 13.802985074626866, p-value: 0.0002030134204354519
#
# Results for NaN_gb vs NaN_mlp:
# Class 0 vs Class 1 - chi-squared: 11.857664233576642, p-value: 0.0005742452328978288
# Class 0 vs Class 2 - chi-squared: 9.316129032258065, p-value: 0.002271453682612269
# Class 1 vs Class 2 - chi-squared: 9.98219584569733, p-value: 0.0015806107874750963
#
# Results for NaN_gb vs custom_rf:
# Class 0 vs Class 1 - chi-squared: 19.396551724137932, p-value: 1.0619863911674108e-05
# Class 0 vs Class 2 - chi-squared: 15.909774436090226, p-value: 6.643473609796127e-05
# Class 1 vs Class 2 - chi-squared: 6.59190031152648, p-value: 0.010244376216845692
#
# Results for NaN_gb vs custom_dt:
# Class 0 vs Class 1 - chi-squared: 6.518518518518518, p-value: 0.010675689620791738
# Class 0 vs Class 2 - chi-squared: 14.291666666666666, p-value: 0.00015655642883761944
# Class 1 vs Class 2 - chi-squared: 7.0892307692307694, p-value: 0.007754852580969428
#
# Results for NaN_gb vs custom_gb:
# Class 0 vs Class 1 - chi-squared: 0.05947955390334572, p-value: 0.8073204255240964
# Class 0 vs Class 2 - chi-squared: 30.22222222222222, p-value: 3.8526973116376616e-08
# Class 1 vs Class 2 - chi-squared: 26.530674846625768, p-value: 2.593865062822265e-07
#
# Results for NaN_gb vs custom_xgb:
# Class 0 vs Class 1 - chi-squared: 6.246621621621622, p-value: 0.012443040766606732
# Class 0 vs Class 2 - chi-squared: 9.920289855072463, p-value: 0.0016346663633757708
# Class 1 vs Class 2 - chi-squared: 8.669753086419753, p-value: 0.0032353502546056618
#
# Results for NaN_gb vs custom_lr:
# Class 0 vs Class 1 - chi-squared: 0.45149253731343286, p-value: 0.5016270231034949
# Class 0 vs Class 2 - chi-squared: 16.92168674698795, p-value: 3.895399180701673e-05
# Class 1 vs Class 2 - chi-squared: 33.07645259938838, p-value: 8.860532235786426e-09
#
# Results for NaN_gb vs oversampling_rf:
# Class 0 vs Class 1 - chi-squared: 4.033333333333333, p-value: 0.04460971802493953
# Class 0 vs Class 2 - chi-squared: 15.340277777777779, p-value: 8.978175298633823e-05
# Class 1 vs Class 2 - chi-squared: 9.845454545454546, p-value: 0.0017025191745218455
#
# Results for NaN_gb vs oversampling_dt:
# Class 0 vs Class 1 - chi-squared: 1.9793814432989691, p-value: 0.15945558560019207
# Class 0 vs Class 2 - chi-squared: 10.50625, p-value: 0.0011897145041076245
# Class 1 vs Class 2 - chi-squared: 3.3201219512195124, p-value: 0.06843675234792684
#
# Results for NaN_gb vs oversampling_gb:
# Class 0 vs Class 1 - chi-squared: 0.18421052631578946, p-value: 0.667779474799556
# Class 0 vs Class 2 - chi-squared: 31.50625, p-value: 1.987993484913753e-08
# Class 1 vs Class 2 - chi-squared: 33.81901840490798, p-value: 6.048467430895075e-09
#
# Results for NaN_gb vs oversampling_xgb:
# Class 0 vs Class 1 - chi-squared: 2.675767918088737, p-value: 0.10188616979808296
# Class 0 vs Class 2 - chi-squared: 19.642857142857142, p-value: 9.335162681359975e-06
# Class 1 vs Class 2 - chi-squared: 12.774193548387096, p-value: 0.0003514340944401315
#
# Results for NaN_gb vs oversampling_lr:
# Class 0 vs Class 1 - chi-squared: 0.48484848484848486, p-value: 0.48623432138829725
# Class 0 vs Class 2 - chi-squared: 0.22085889570552147, p-value: 0.6383862608182801
# Class 1 vs Class 2 - chi-squared: 4.923076923076923, p-value: 0.026500280602491884
#
# Results for NaN_xgb vs NaN_lr:
# Class 0 vs Class 1 - chi-squared: 18.56271186440678, p-value: 1.6440517899841e-05
# Class 0 vs Class 2 - chi-squared: 9.437908496732026, p-value: 0.0021254574441375504
# Class 1 vs Class 2 - chi-squared: 4.923076923076923, p-value: 0.026500280602491884
#
# Results for NaN_xgb vs NaN_mlp:
# Class 0 vs Class 1 - chi-squared: 5.756849315068493, p-value: 0.016424498256039265
# Class 0 vs Class 2 - chi-squared: 1.0432098765432098, p-value: 0.3070761128977339
# Class 1 vs Class 2 - chi-squared: 2.7522935779816513, p-value: 0.09711502842708813
#
# Results for NaN_xgb vs custom_rf:
# Class 0 vs Class 1 - chi-squared: 11.301948051948052, p-value: 0.0007742581211164217
# Class 0 vs Class 2 - chi-squared: 3.15, p-value: 0.07592696298255787
# Class 1 vs Class 2 - chi-squared: 1.0418006430868167, p-value: 0.3074030594739051
#
# Results for NaN_xgb vs custom_dt:
# Class 0 vs Class 1 - chi-squared: 2.488888888888889, p-value: 0.1146526416844945
# Class 0 vs Class 2 - chi-squared: 3.2914285714285714, p-value: 0.06964240479832816
# Class 1 vs Class 2 - chi-squared: 1.2698412698412698, p-value: 0.2597964596779385
#
# Results for NaN_xgb vs custom_gb:
# Class 0 vs Class 1 - chi-squared: 0.34843205574912894, p-value: 0.5550020500134405
# Class 0 vs Class 2 - chi-squared: 11.55625, p-value: 0.0006752189819075748
# Class 1 vs Class 2 - chi-squared: 13.370253164556962, p-value: 0.0002556468436190802
#
# Results for NaN_xgb vs custom_xgb:
# Class 0 vs Class 1 - chi-squared: 2.321656050955414, p-value: 0.12758413193394175
# Class 0 vs Class 2 - chi-squared: 0.993103448275862, p-value: 0.31898504576039544
# Class 1 vs Class 2 - chi-squared: 1.9904458598726114, p-value: 0.1582942685946399
#
# Results for NaN_xgb vs custom_lr:
# Class 0 vs Class 1 - chi-squared: 0.03146853146853147, p-value: 0.8591991407511987
# Class 0 vs Class 2 - chi-squared: 4.531791907514451, p-value: 0.033270762967007574
# Class 1 vs Class 2 - chi-squared: 18.22082018927445, p-value: 1.9671663019831876e-05
#
# Results for NaN_xgb vs oversampling_rf:
# Class 0 vs Class 1 - chi-squared: 1.0034722222222223, p-value: 0.31647178784797536
# Class 0 vs Class 2 - chi-squared: 3.205298013245033, p-value: 0.0734001356410793
# Class 1 vs Class 2 - chi-squared: 2.628125, p-value: 0.10498562654568092
#
# Results for NaN_xgb vs oversampling_dt:
# Class 0 vs Class 1 - chi-squared: 0.20711974110032363, p-value: 0.6490343491133049
# Class 0 vs Class 2 - chi-squared: 1.532934131736527, p-value: 0.2156726174882228
# Class 1 vs Class 2 - chi-squared: 0.07861635220125786, p-value: 0.7791813177369804
#
# Results for NaN_xgb vs oversampling_gb:
# Class 0 vs Class 1 - chi-squared: 1.8626760563380282, p-value: 0.17231626246838871
# Class 0 vs Class 2 - chi-squared: 12.67065868263473, p-value: 0.0003714386546112936
# Class 1 vs Class 2 - chi-squared: 18.7626582278481, p-value: 1.480374763654609e-05
#
# Results for NaN_xgb vs oversampling_xgb:
# Class 0 vs Class 1 - chi-squared: 0.4630225080385852, p-value: 0.49621477753974996
# Class 0 vs Class 2 - chi-squared: 5.590062111801243, p-value: 0.018062655671126745
# Class 1 vs Class 2 - chi-squared: 4.362537764350453, p-value: 0.036737538458275536
#
# Results for NaN_xgb vs oversampling_lr:
# Class 0 vs Class 1 - chi-squared: 0.012698412698412698, p-value: 0.9102785225994081
# Class 0 vs Class 2 - chi-squared: 1.7, p-value: 0.19228797711151613
# Class 1 vs Class 2 - chi-squared: 0.45714285714285713, p-value: 0.49896229860376107
#
# Results for NaN_lr vs NaN_mlp:
# Class 0 vs Class 1 - chi-squared: 13.487719298245613, p-value: 0.0002401298860693929
# Class 0 vs Class 2 - chi-squared: 4.096969696969697, p-value: 0.04296014602842514
# Class 1 vs Class 2 - chi-squared: 9.845454545454546, p-value: 0.0017025191745218455
#
# Results for NaN_lr vs custom_rf:
# Class 0 vs Class 1 - chi-squared: 21.262458471760798, p-value: 4.004988051793473e-06
# Class 0 vs Class 2 - chi-squared: 8.083916083916083, p-value: 0.004465983415933228
# Class 1 vs Class 2 - chi-squared: 6.449044585987261, p-value: 0.011101202406874327
#
# Results for NaN_lr vs custom_dt:
# Class 0 vs Class 1 - chi-squared: 7.795454545454546, p-value: 0.005237783216859279
# Class 0 vs Class 2 - chi-squared: 7.691011235955056, p-value: 0.005549652379429616
# Class 1 vs Class 2 - chi-squared: 6.946540880503145, p-value: 0.008398146632202392
#
# Results for NaN_lr vs custom_gb:
# Class 0 vs Class 1 - chi-squared: 0.2892857142857143, p-value: 0.590678625296306
# Class 0 vs Class 2 - chi-squared: 19.23926380368098, p-value: 1.1531705548718808e-05
# Class 1 vs Class 2 - chi-squared: 26.53291536050157, p-value: 2.59085851368117e-07
#
# Results for NaN_lr vs custom_xgb:
# Class 0 vs Class 1 - chi-squared: 7.504885993485342, p-value: 0.006153183529152768
# Class 0 vs Class 2 - chi-squared: 4.222972972972973, p-value: 0.03988022740117013
# Class 1 vs Class 2 - chi-squared: 8.529968454258675, p-value: 0.0034934575494663146
#
# Results for NaN_lr vs custom_lr:
# Class 0 vs Class 1 - chi-squared: 0.9175627240143369, p-value: 0.3381157361573088
# Class 0 vs Class 2 - chi-squared: 9.551136363636363, p-value: 0.0019982567083017978
# Class 1 vs Class 2 - chi-squared: 33.153125, p-value: 8.517936949898794e-09
#
# Results for NaN_lr vs oversampling_rf:
# Class 0 vs Class 1 - chi-squared: 5.1387900355871885, p-value: 0.023396949450357554
# Class 0 vs Class 2 - chi-squared: 7.954545454545454, p-value: 0.00479667541887454
# Class 1 vs Class 2 - chi-squared: 9.708978328173375, p-value: 0.001833699284829709
#
# Results for NaN_lr vs oversampling_dt:
# Class 0 vs Class 1 - chi-squared: 2.7847682119205297, p-value: 0.09516446138222527
# Class 0 vs Class 2 - chi-squared: 4.947058823529412, p-value: 0.02613509411386816
# Class 1 vs Class 2 - chi-squared: 3.190031152647975, p-value: 0.07408859979688802
#
# Results for NaN_lr vs oversampling_gb:
# Class 0 vs Class 1 - chi-squared: 0.01444043321299639, p-value: 0.9043497862275144
# Class 0 vs Class 2 - chi-squared: 20.476470588235294, p-value: 6.036882921493148e-06
# Class 1 vs Class 2 - chi-squared: 33.905956112852664, p-value: 5.784135611434327e-09
#
# Results for NaN_lr vs oversampling_xgb:
# Class 0 vs Class 1 - chi-squared: 3.5822368421052633, p-value: 0.05840046371254665
# Class 0 vs Class 2 - chi-squared: 11.274390243902438, p-value: 0.0007858366216931769
# Class 1 vs Class 2 - chi-squared: 12.649700598802395, p-value: 0.0003756258281835836
#
# Results for NaN_lr vs oversampling_lr:
# Class 0 vs Class 1 - chi-squared: 0.9383116883116883, p-value: 0.3327124107582658
# Class 0 vs Class 2 - chi-squared: 0.09248554913294797, p-value: 0.761040760480224
# Class 1 vs Class 2 - chi-squared: 4.783018867924528, p-value: 0.02874169171978658
#
# Results for NaN_mlp vs custom_rf:
# Class 0 vs Class 1 - chi-squared: 7.412751677852349, p-value: 0.006476319487689536
# Class 0 vs Class 2 - chi-squared: 0.5328947368421053, p-value: 0.4653923881242662
# Class 1 vs Class 2 - chi-squared: 3.8765822784810124, p-value: 0.04896413605518504
#
# Results for NaN_mlp vs custom_dt:
# Class 0 vs Class 1 - chi-squared: 0.839344262295082, p-value: 0.3595843794802377
# Class 0 vs Class 2 - chi-squared: 0.7700534759358288, p-value: 0.3802005096254406
# Class 1 vs Class 2 - chi-squared: 4.278125, p-value: 0.03860591307070306
#
# Results for NaN_mlp vs custom_gb:
# Class 0 vs Class 1 - chi-squared: 1.7472924187725631, p-value: 0.18621747540187145
# Class 0 vs Class 2 - chi-squared: 5.587209302325581, p-value: 0.0180920980680049
# Class 1 vs Class 2 - chi-squared: 20.947040498442366, p-value: 4.721566809335498e-06
#
# Results for NaN_mlp vs custom_xgb:
# Class 0 vs Class 1 - chi-squared: 0.7401315789473685, p-value: 0.3896187319493749
# Class 0 vs Class 2 - chi-squared: 0.0, p-value: 1.0
# Class 1 vs Class 2 - chi-squared: 5.529780564263323, p-value: 0.018695449892612997
#
# Results for NaN_mlp vs custom_lr:
# Class 0 vs Class 1 - chi-squared: 0.8152173913043478, p-value: 0.3665822094105118
# Class 0 vs Class 2 - chi-squared: 1.3837837837837839, p-value: 0.23945768135225556
# Class 1 vs Class 2 - chi-squared: 26.86024844720497, p-value: 2.1871145980303073e-07
#
# Results for NaN_mlp vs oversampling_rf:
# Class 0 vs Class 1 - chi-squared: 0.08992805755395683, p-value: 0.764268635459968
# Class 0 vs Class 2 - chi-squared: 0.6134969325153374, p-value: 0.4334741831595069
# Class 1 vs Class 2 - chi-squared: 6.510769230769231, p-value: 0.010722311518222864
#
# Results for NaN_mlp vs oversampling_dt:
# Class 0 vs Class 1 - chi-squared: 0.013377926421404682, p-value: 0.9079196418925198
# Class 0 vs Class 2 - chi-squared: 0.0893854748603352, p-value: 0.7649598554295175
# Class 1 vs Class 2 - chi-squared: 1.498452012383901, p-value: 0.2209096987962421
#
# Results for NaN_mlp vs oversampling_gb:
# Class 0 vs Class 1 - chi-squared: 4.470802919708029, p-value: 0.03447878573157675
# Class 0 vs Class 2 - chi-squared: 6.4581005586592175, p-value: 0.011044764603214073
# Class 1 vs Class 2 - chi-squared: 27.526479750778815, p-value: 1.5495835250224478e-07
#
# Results for NaN_mlp vs oversampling_xgb:
# Class 0 vs Class 1 - chi-squared: 0.0, p-value: 1.0
# Class 0 vs Class 2 - chi-squared: 1.8728323699421965, p-value: 0.17115103691704958
# Class 1 vs Class 2 - chi-squared: 9.00297619047619, p-value: 0.002695403021023154
#
# Results for NaN_mlp vs oversampling_lr:
# Class 0 vs Class 1 - chi-squared: 0.6426229508196721, p-value: 0.4227625816767968
# Class 0 vs Class 2 - chi-squared: 4.6208791208791204, p-value: 0.03158504615162933
# Class 1 vs Class 2 - chi-squared: 2.628125, p-value: 0.10498562654568092
#
# Results for custom_rf vs custom_dt:
# Class 0 vs Class 1 - chi-squared: 3.601246105919003, p-value: 0.05773627880490786
# Class 0 vs Class 2 - chi-squared: 2.4242424242424243, p-value: 0.11947098677170034
# Class 1 vs Class 2 - chi-squared: 2.0559210526315788, p-value: 0.15161554768680843
#
# Results for custom_rf vs custom_gb:
# Class 0 vs Class 1 - chi-squared: 0.05460750853242321, p-value: 0.815231478398684
# Class 0 vs Class 2 - chi-squared: 10.14, p-value: 0.001450861633360639
# Class 1 vs Class 2 - chi-squared: 16.065573770491802, p-value: 6.1186316734512e-05
#
# Results for custom_rf vs custom_xgb:
# Class 0 vs Class 1 - chi-squared: 3.403125, p-value: 0.06507302877538931
# Class 0 vs Class 2 - chi-squared: 0.4740740740740741, p-value: 0.4911188504806726
# Class 1 vs Class 2 - chi-squared: 2.9702970297029703, p-value: 0.08480628179936685
#
# Results for custom_rf vs custom_lr:
# Class 0 vs Class 1 - chi-squared: 0.003424657534246575, p-value: 0.9533339752146197
# Class 0 vs Class 2 - chi-squared: 3.5337423312883436, p-value: 0.0601319211915922
# Class 1 vs Class 2 - chi-squared: 21.441176470588236, p-value: 3.6485109408413597e-06
#
# Results for custom_rf vs oversampling_rf:
# Class 0 vs Class 1 - chi-squared: 1.7993197278911566, p-value: 0.1797947582207586
# Class 0 vs Class 2 - chi-squared: 2.297872340425532, p-value: 0.12955135290440867
# Class 1 vs Class 2 - chi-squared: 3.7411003236245954, p-value: 0.053089473826264826
#
# Results for custom_rf vs oversampling_dt:
# Class 0 vs Class 1 - chi-squared: 0.6222222222222222, p-value: 0.43022269113219136
# Class 0 vs Class 2 - chi-squared: 0.9171974522292994, p-value: 0.3382119073466782
# Class 1 vs Class 2 - chi-squared: 0.3257328990228013, p-value: 0.5681825809670168
#
# Results for custom_rf vs oversampling_gb:
# Class 0 vs Class 1 - chi-squared: 0.996551724137931, p-value: 0.3181463307462504
# Class 0 vs Class 2 - chi-squared: 11.235668789808917, p-value: 0.0008024018698769247
# Class 1 vs Class 2 - chi-squared: 22.04590163934426, p-value: 2.662074682202685e-06
#
# Results for custom_rf vs oversampling_xgb:
# Class 0 vs Class 1 - chi-squared: 1.0220820189274449, p-value: 0.3120256570000594
# Class 0 vs Class 2 - chi-squared: 4.47682119205298, p-value: 0.03435756766514093
# Class 1 vs Class 2 - chi-squared: 5.778125, p-value: 0.01622684256784749
#
# Results for custom_rf vs oversampling_lr:
# Class 0 vs Class 1 - chi-squared: 0.012461059190031152, p-value: 0.9111174863108885
# Class 0 vs Class 2 - chi-squared: 2.75625, p-value: 0.09687507502627439
# Class 1 vs Class 2 - chi-squared: 0.9506578947368421, p-value: 0.3295518923985569
#
# Results for custom_dt vs custom_gb:
# Class 0 vs Class 1 - chi-squared: 4.083333333333333, p-value: 0.04330814281079206
# Class 0 vs Class 2 - chi-squared: 9.535135135135135, p-value: 0.0020157533091078486
# Class 1 vs Class 2 - chi-squared: 16.776699029126213, p-value: 4.204644665909837e-05
#
# Results for custom_dt vs custom_xgb:
# Class 0 vs Class 1 - chi-squared: 0.012232415902140673, p-value: 0.9119333470737875
# Class 0 vs Class 2 - chi-squared: 0.711764705882353, p-value: 0.39885859409376656
# Class 1 vs Class 2 - chi-squared: 3.3355048859934855, p-value: 0.0677995956076595
#
# Results for custom_dt vs custom_lr:
# Class 0 vs Class 1 - chi-squared: 2.6220735785953178, p-value: 0.10538664272211506
# Class 0 vs Class 2 - chi-squared: 3.6818181818181817, p-value: 0.055008833629265896
# Class 1 vs Class 2 - chi-squared: 22.22258064516129, p-value: 2.4280141818569275e-06
#
# Results for custom_dt vs oversampling_rf:
# Class 0 vs Class 1 - chi-squared: 0.11960132890365449, p-value: 0.7294672832904731
# Class 0 vs Class 2 - chi-squared: 2.5056818181818183, p-value: 0.11343638083618238
# Class 1 vs Class 2 - chi-squared: 4.140575079872204, p-value: 0.04186694378663211
#
# Results for custom_dt vs oversampling_dt:
# Class 0 vs Class 1 - chi-squared: 0.6987577639751553, p-value: 0.4032014186074985
# Class 0 vs Class 2 - chi-squared: 1.171875, p-value: 0.27901631321136067
# Class 1 vs Class 2 - chi-squared: 0.4630225080385852, p-value: 0.49621477753974996
#
# Results for custom_dt vs oversampling_gb:
# Class 0 vs Class 1 - chi-squared: 7.757575757575758, p-value: 0.005348770520482035
# Class 0 vs Class 2 - chi-squared: 10.546875, p-value: 0.001163846957730243
# Class 1 vs Class 2 - chi-squared: 22.83495145631068, p-value: 1.7652607362074436e-06
#
# Results for custom_dt vs oversampling_xgb:
# Class 0 vs Class 1 - chi-squared: 0.3734567901234568, p-value: 0.5411260244716681
# Class 0 vs Class 2 - chi-squared: 4.521505376344086, p-value: 0.033471368134577545
# Class 1 vs Class 2 - chi-squared: 6.25, p-value: 0.01241933065155227
#
# Results for custom_dt vs oversampling_lr:
# Class 0 vs Class 1 - chi-squared: 2.222560975609756, p-value: 0.13600728822422764
# Class 0 vs Class 2 - chi-squared: 1.6615384615384616, p-value: 0.19739573184449527
# Class 1 vs Class 2 - chi-squared: 1.172077922077922, p-value: 0.2789746945154239
#
# Results for custom_gb vs custom_xgb:
# Class 0 vs Class 1 - chi-squared: 4.334448160535117, p-value: 0.03734852103011016
# Class 0 vs Class 2 - chi-squared: 5.806451612903226, p-value: 0.015967481126056837
# Class 1 vs Class 2 - chi-squared: 19.25, p-value: 1.1467037826363588e-05
#
# Results for custom_gb vs custom_lr:
# Class 0 vs Class 1 - chi-squared: 17.062730627306273, p-value: 3.6165112747033684e-05
# Class 0 vs Class 2 - chi-squared: 11.562841530054644, p-value: 0.0006728295058485816
# Class 1 vs Class 2 - chi-squared: 52.68167202572347, p-value: 3.922343570671845e-13
#
# Results for custom_gb vs oversampling_rf:
# Class 0 vs Class 1 - chi-squared: 7.750915750915751, p-value: 0.005368531212071257
# Class 0 vs Class 2 - chi-squared: 9.937888198757763, p-value: 0.0016191119156048661
# Class 1 vs Class 2 - chi-squared: 20.894904458598727, p-value: 4.851835268522884e-06
#
# Results for custom_gb vs oversampling_dt:
# Class 0 vs Class 1 - chi-squared: 10.289115646258503, p-value: 0.0013381720899189305
# Class 0 vs Class 2 - chi-squared: 6.531073446327683, p-value: 0.010600596465354651
# Class 1 vs Class 2 - chi-squared: 10.413461538461538, p-value: 0.0012510003005978502
#
# Results for custom_gb vs oversampling_gb:
# Class 0 vs Class 1 - chi-squared: 28.78810408921933, p-value: 8.07455464114967e-08
# Class 0 vs Class 2 - chi-squared: 23.141242937853107, p-value: 1.5052715796177565e-06
# Class 1 vs Class 2 - chi-squared: 53.68064516129032, p-value: 2.3587558024746424e-13
#
# Results for custom_gb vs oversampling_xgb:
# Class 0 vs Class 1 - chi-squared: 8.787162162162161, p-value: 0.003033577931501552
# Class 0 vs Class 2 - chi-squared: 13.473684210526315, p-value: 0.00024193279086066012
# Class 1 vs Class 2 - chi-squared: 24.923076923076923, p-value: 5.96639383307014e-07
#
# Results for custom_gb vs oversampling_lr:
# Class 0 vs Class 1 - chi-squared: 14.963333333333333, p-value: 0.00010962068302139609
# Class 0 vs Class 2 - chi-squared: 0.005555555555555556, p-value: 0.9405842158297484
# Class 1 vs Class 2 - chi-squared: 13.255663430420713, p-value: 0.00027175758991110073
#
# Results for custom_xgb vs custom_lr:
# Class 0 vs Class 1 - chi-squared: 2.8221476510067114, p-value: 0.09297192952525564
# Class 0 vs Class 2 - chi-squared: 1.3392857142857142, p-value: 0.24715997321190386
# Class 1 vs Class 2 - chi-squared: 25.06148867313916, p-value: 5.553090579927879e-07
#
# Results for custom_xgb vs oversampling_rf:
# Class 0 vs Class 1 - chi-squared: 0.16333333333333333, p-value: 0.6861059569955557
# Class 0 vs Class 2 - chi-squared: 0.5547945205479452, p-value: 0.45636524623205876
# Class 1 vs Class 2 - chi-squared: 5.387820512820513, p-value: 0.020277782837364037
#
# Results for custom_xgb vs oversampling_dt:
# Class 0 vs Class 1 - chi-squared: 0.7975077881619937, p-value: 0.37183954599721347
# Class 0 vs Class 2 - chi-squared: 0.05555555555555555, p-value: 0.8136637157667919
# Class 1 vs Class 2 - chi-squared: 0.932258064516129, p-value: 0.33427685502641485
#
# Results for custom_xgb vs oversampling_gb:
# Class 0 vs Class 1 - chi-squared: 8.111486486486486, p-value: 0.004398564269386018
# Class 0 vs Class 2 - chi-squared: 6.722222222222222, p-value: 0.009521891184098848
# Class 1 vs Class 2 - chi-squared: 25.717532467532468, p-value: 3.9522021997166184e-07
#
# Results for custom_xgb vs oversampling_xgb:
# Class 0 vs Class 1 - chi-squared: 0.4458204334365325, p-value: 0.5043264757421704
# Class 0 vs Class 2 - chi-squared: 1.8525641025641026, p-value: 0.1734854683214746
# Class 1 vs Class 2 - chi-squared: 7.739938080495356, p-value: 0.005401265296787171
#
# Results for custom_xgb vs oversampling_lr:
# Class 0 vs Class 1 - chi-squared: 2.397553516819572, p-value: 0.12152516991741305
# Class 0 vs Class 2 - chi-squared: 5.454545454545454, p-value: 0.019517481182177752
# Class 1 vs Class 2 - chi-squared: 1.8762214983713354, p-value: 0.17076422125540947
#
# Results for custom_lr vs oversampling_rf:
# Class 0 vs Class 1 - chi-squared: 5.591911764705882, p-value: 0.018043592782942718
# Class 0 vs Class 2 - chi-squared: 3.5919540229885056, p-value: 0.05805993653705126
# Class 1 vs Class 2 - chi-squared: 26.86984126984127, p-value: 2.176285487773449e-07
#
# Results for custom_lr vs oversampling_dt:
# Class 0 vs Class 1 - chi-squared: 7.863481228668942, p-value: 0.005044317865733486
# Class 0 vs Class 2 - chi-squared: 1.9, p-value: 0.1680783190349663
# Class 1 vs Class 2 - chi-squared: 14.773162939297125, p-value: 0.00012124886526441264
#
# Results for custom_lr vs oversampling_gb:
# Class 0 vs Class 1 - chi-squared: 24.48134328358209, p-value: 7.50328814619237e-07
# Class 0 vs Class 2 - chi-squared: 12.636842105263158, p-value: 0.0003782183344630197
# Class 1 vs Class 2 - chi-squared: 63.02250803858521, p-value: 2.0435791688027933e-15
#
# Results for custom_lr vs oversampling_xgb:
# Class 0 vs Class 1 - chi-squared: 6.562711864406779, p-value: 0.010413754783408944
# Class 0 vs Class 2 - chi-squared: 5.918478260869565, p-value: 0.01498289369007811
# Class 1 vs Class 2 - chi-squared: 31.291411042944784, p-value: 2.220598816562862e-08
#
# Results for custom_lr vs oversampling_lr:
# Class 0 vs Class 1 - chi-squared: 12.040133779264215, p-value: 0.0005206723464310221
# Class 0 vs Class 2 - chi-squared: 1.0155440414507773, p-value: 0.3135783118844856
# Class 1 vs Class 2 - chi-squared: 18.14516129032258, p-value: 2.046888659218587e-05
#
# Results for oversampling_rf vs oversampling_dt:
# Class 0 vs Class 1 - chi-squared: 2.2915254237288134, p-value: 0.1300820209361701
# Class 0 vs Class 2 - chi-squared: 1.005952380952381, p-value: 0.31587447983048655
# Class 1 vs Class 2 - chi-squared: 1.3955696202531647, p-value: 0.23746677131689994
#
# Results for oversampling_rf vs oversampling_gb:
# Class 0 vs Class 1 - chi-squared: 12.892592592592592, p-value: 0.0003298851465757489
# Class 0 vs Class 2 - chi-squared: 11.005952380952381, p-value: 0.0009081975515243088
# Class 1 vs Class 2 - chi-squared: 27.544585987261147, p-value: 1.5351448242063382e-07
#
# Results for oversampling_rf vs oversampling_xgb:
# Class 0 vs Class 1 - chi-squared: 1.6296296296296295, p-value: 0.2017542836280726
# Class 0 vs Class 2 - chi-squared: 4.5, p-value: 0.033894853524689295
# Class 1 vs Class 2 - chi-squared: 8.863221884498481, p-value: 0.0029097354257567342
#
# Results for oversampling_rf vs oversampling_lr:
# Class 0 vs Class 1 - chi-squared: 4.79734219269103, p-value: 0.028503676397605385
# Class 0 vs Class 2 - chi-squared: 2.3391812865497075, p-value: 0.12615584218022652
# Class 1 vs Class 2 - chi-squared: 2.5047923322683707, p-value: 0.11350044562733456
#
# Results for oversampling_dt vs oversampling_gb:
# Class 0 vs Class 1 - chi-squared: 15.890034364261169, p-value: 6.713127146273786e-05
# Class 0 vs Class 2 - chi-squared: 7.440217391304348, p-value: 0.006378218540458449
# Class 1 vs Class 2 - chi-squared: 15.259615384615385, p-value: 9.36985285211981e-05
#
# Results for oversampling_dt vs oversampling_xgb:
# Class 0 vs Class 1 - chi-squared: 3.0220125786163523, p-value: 0.0821414699538615
# Class 0 vs Class 2 - chi-squared: 2.4775280898876404, p-value: 0.11548362406597744
# Class 1 vs Class 2 - chi-squared: 2.7522935779816513, p-value: 0.09711502842708813
#
# Results for oversampling_dt vs oversampling_lr:
# Class 0 vs Class 1 - chi-squared: 6.8602484472049685, p-value: 0.008813429382123464
# Class 0 vs Class 2 - chi-squared: 3.6149732620320854, p-value: 0.057261642197154024
# Class 1 vs Class 2 - chi-squared: 0.05144694533762058, p-value: 0.8205643404450812
#
# Results for oversampling_gb vs oversampling_xgb:
# Class 0 vs Class 1 - chi-squared: 13.979522184300341, p-value: 0.00018481258065388632
# Class 0 vs Class 2 - chi-squared: 14.612359550561798, p-value: 0.0001320456763959242
# Class 1 vs Class 2 - chi-squared: 32.012307692307694, p-value: 1.5319888458347274e-08
#
# Results for oversampling_gb vs oversampling_lr:
# Class 0 vs Class 1 - chi-squared: 21.54882154882155, p-value: 3.449345750127958e-06
# Class 0 vs Class 2 - chi-squared: 0.0213903743315508, p-value: 0.883720495258396
# Class 1 vs Class 2 - chi-squared: 18.692556634304207, p-value: 1.535808393817177e-05
#
# Results for oversampling_xgb vs oversampling_lr:
# Class 0 vs Class 1 - chi-squared: 5.70679012345679, p-value: 0.016899412424501714
# Class 0 vs Class 2 - chi-squared: 0.7955801104972375, p-value: 0.3724181380009668
# Class 1 vs Class 2 - chi-squared: 4.2253086419753085, p-value: 0.03982537549955067
